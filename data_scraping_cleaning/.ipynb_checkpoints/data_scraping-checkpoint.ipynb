# %%
import bs4
from bs4 import BeautifulSoup
import requests
import re
import pandas as pd
import numpy as np
import os
from time import time
import smtplib
import locale
locale.setlocale( locale.LC_ALL, '' )
# Out:
# 'English_United States.1252'

# %% [markdown]
# ### 1. Scrape beer style list

# %%
# Scrape list of beer styles from beeradvocate.com
if os.path.exists("styles.csv"):
    print("Style list is already scraped")

else:
    url="https://www.beeradvocate.com/beer/style/"
    r = requests.get(url)
    soup = BeautifulSoup(r.content,"lxml")

    styles=soup.find_all(href=re.compile("/beer/style/"))
    names=[]
    links=[]
    for style in styles:
        name=style.contents[0]
        link="https://www.beeradvocate.com"+style.get("href")
        names.append(name)
        links.append(link)

    links=links[2:-1]
    names=names[2:-1]
    style_ids=[link.split("/")[-2] for link in links]

    style_table=pd.DataFrame({"style":pd.Series(names),"link":pd.Series(links),"id":pd.Series(style_ids)})
    style_table.to_csv("styles.csv", encoding="utf-8")
# Out:
# Style list is already scraped

# %% [markdown]
# ### 2. Scrape beer list by style

# %%
# Read pre-saved list of beer styles
styles=pd.read_csv("styles.csv", encoding="utf-8")
links=styles["link"]
names=styles["style"]
ids=styles["id"]

# %%
# Scrape beers of each styles from beeradvocate.com
style_id=0

while style_id<len(names):
    style_url=links[style_id]
    style_name = "style_"+str(ids[style_id])+".csv"
    if os.path.exists(style_name):
        print("{} already existed".format(style_name))
        next
    else:
        r = requests.get(style_url)
        soup = BeautifulSoup(r.content,"lxml")
        print("Start parsing {}".format(names[style_id]))

        indexs=soup.find_all(href=re.compile(style_url[29:]+"\?sort\=revsD\&start\="))
        for ind in indexs:
            if ind.contents[0]=="last":
                last_page=int(ind.get("href").split("=")[-1])
                break
        print("Total items: {}".format(last_page))

        beer_names=[]
        beer_ids=[]
        companys=[]
        company_ids=[]
        abvs=[]
        ratings=[]
        scores=[]
        beer_links=[]

        page=0

        while page*50<=last_page:
            beer_url=style_url+"?sort=revsD&start="+str(page*50)
            r = requests.get(beer_url)
            soup = BeautifulSoup(r.content,"lxml")
            beers=soup.find_all(class_="hr_bottom_light")
            assert len(beers)%5==0
            for i in range(int(len(beers)/5)):
                beer_name = beers[i*5].contents[0].contents[0].contents[0]
                beer_id = beers[i*5].contents[0].get("href").split("/")[-2]
                company = beers[i*5+1].contents[0].contents[0]
                company_id = beers[i*5].contents[0].get("href").split("/")[-3]
                abv = beers[i*5+2].contents[0].contents[0]
                rating = beers[i*5+3].contents[0].contents[0]
                score = beers[i*5+4].contents[0].contents[0]
                beer_link="https://www.beeradvocate.com/beer/profile/"+company_id+"/"+beer_id+"/"

                beer_names.append(beer_name)
                beer_ids.append(beer_id)
                companys.append(company)
                company_ids.append(company_id)
                abvs.append(abv)
                ratings.append(rating)
                scores.append(score)
                beer_links.append(beer_link)

        page+=1

        df=pd.DataFrame({"beer_names":pd.Series(beer_names),"beer_ids":pd.Series(beer_ids),"companys":pd.Series(companys),
                         "company_ids":pd.Series(company_ids),"abvs":pd.Series(abvs),"ratings":pd.Series(ratings),"scores":pd.Series(scores),
                        "beer_links":pd.Series(beer_links)})

        df.to_csv(style_name, encoding="utf-8")
        print("{} completed".format(style_name))
        print("Total beers: {}".format(df.shape[0]))
    style_id+=1
# Out:
# style_128.csv already existed
# style_19.csv already existed
# style_175.csv already existed
# style_99.csv already existed
# style_73.csv already existed
# style_94.csv already existed
# style_140.csv already existed
# style_157.csv already existed
# style_116.csv already existed
# style_97.csv already existed
# style_93.csv already existed
# style_159.csv already existed
# style_158.csv already existed
# style_78.csv already existed
# style_171.csv already existed
# style_130.csv already existed
# style_163.csv already existed
# style_6.csv already existed
# style_72.csv already existed
# style_12.csv already existed
# style_60.csv already existed
# style_119.csv already existed
# style_174.csv already existed
# style_54.csv already existed
# style_56.csv already existed
# style_55.csv already existed
# style_141.csv already existed
# style_127.csv already existed
# style_57.csv already existed
# style_15.csv already existed
# style_52.csv already existed
# style_53.csv already existed
# style_14.csv already existed
# style_10.csv already existed
# style_50.csv already existed
# style_142.csv already existed
# style_129.csv already existed
# style_58.csv already existed
# style_48.csv already existed
# style_80.csv already existed
# style_114.csv already existed
# style_152.csv already existed
# style_98.csv already existed
# style_74.csv already existed
# style_75.csv already existed
# style_150.csv already existed
# style_154.csv already existed
# style_76.csv already existed
# style_101.csv already existed
# style_13.csv already existed
# style_165.csv already existed
# style_66.csv already existed
# style_95.csv already existed
# style_82.csv already existed
# style_69.csv already existed
# style_79.csv already existed
# style_84.csv already existed
# style_47.csv already existed
# style_148.csv already existed
# style_86.csv already existed
# style_87.csv already existed
# style_91.csv already existed
# style_16.csv already existed
# style_89.csv already existed
# style_85.csv already existed
# style_90.csv already existed
# style_18.csv already existed
# style_92.csv already existed
# style_162.csv already existed
# style_161.csv already existed
# style_173.csv already existed
# style_77.csv already existed
# style_68.csv already existed
# style_70.csv already existed
# style_38.csv already existed
# style_147.csv already existed
# style_164.csv already existed
# style_42.csv already existed
# style_155.csv already existed
# style_132.csv already existed
# style_39.csv already existed
# style_5.csv already existed
# style_40.csv already existed
# style_149.csv already existed
# style_37.csv already existed
# style_43.csv already existed
# style_32.csv already existed
# style_35.csv already existed
# style_20.csv already existed
# style_36.csv already existed
# style_41.csv already existed
# style_131.csv already existed
# style_33.csv already existed
# style_29.csv already existed
# style_46.csv already existed
# style_21.csv already existed
# style_7.csv already existed
# style_31.csv already existed
# style_30.csv already existed
# style_168.csv already existed
# style_169.csv already existed
# style_9.csv already existed
# style_8.csv already existed
# style_11.csv already existed

# %% [markdown]
# ### 3. Scrape brewery info

# %%
# Read pre-saved list of beer styles
styles=pd.read_csv("styles.csv", encoding="utf-8")
names=styles["style"]
ids=styles["id"]


# Get unique company lists
style_id=0

company_ids=set([])

while style_id<len(names):
    style_name = "style_"+str(ids[style_id])+".csv"
    df=pd.read_csv(style_name, encoding="utf-8")
    company_ids.update(df["company_ids"].tolist())
    style_id+=1

company_ids=list(company_ids)

df=pd.DataFrame({"company_ids":pd.Series(company_ids)})

df.to_csv("company_ids.csv",encoding="utf-8")
print("{} companies recorded".format(len(company_ids)))
# Out:
# 13939 companies recorded

# %%
company_ids=pd.read_csv("company_ids.csv",encoding="utf-8")["company_ids"].tolist()

try:
    df=pd.read_csv("company.csv",encoding="utf-8")

    company_urls=df["company_urls"].tolist()
    company_names=df["company_names"].tolist()
    location1s=df["location1s"].tolist()
    location2s=df["location2s"].tolist()

    ba_scores=df["ba_scores"].tolist()
    ba_levels=df["ba_levels"].tolist()
    total_ratings=df["total_ratings"].tolist()

    beer_currents=df["beer_currents"].tolist()
    total_reviews=df["total_reviews"].tolist()
    
except FileNotFoundError:
    company_urls=[]
    company_names=[]
    location1s=[]
    location2s=[]

    ba_scores=[]
    ba_levels=[]
    total_ratings=[]

    beer_currents=[]
    total_reviews=[]
    
    
i=len(company_urls)
print("{} companies information already scraped".format(i))

while i<len(company_ids):
    comp_id=company_ids[i]
    company_url="https://www.beeradvocate.com/beer/profile/"+str(comp_id)+"/"
    r = requests.get(company_url)
    soup = BeautifulSoup(r.content,"lxml")
    
    company_info=soup.find_all(attrs={"name": "keywords"}) [0].get("content")
    score_summary=soup.find_all(id="score_box")[0].contents
    score_detail=soup.find_all(id="item_stats")[0].contents[1].contents

    company_name=company_info.split(",")[0]
    try:
        location1=company_info.split(",")[1]
    except IndexError:
        location1="NA"   

    try:
        location2=company_info.split(",")[2]
    except IndexError:
        location2="NA"

    ba_score=score_summary[6].contents[0].contents[0]
    try:
        ba_level=score_summary[10].contents[0]
    except IndexError:
        ba_level="NA"
    total_rating=score_summary[-1].split("\t")[0]

    beer_current=score_detail[3].contents[0]
    total_review=score_detail[7].contents[0]
    
    company_urls.append(company_url)
    company_names.append(company_name)
    location1s.append(location1)
    location2s.append(location2)
    ba_scores.append(ba_score)
    ba_levels.append(ba_level)
    total_ratings.append(total_rating)
    beer_currents.append(beer_current)
    total_reviews.append(total_review)
    print("Finished: {}".format(i))
    i+=1

    
companys=pd.DataFrame({"company_ids":pd.Series(company_ids[0:len(ba_scores)]),"company_urls":pd.Series(company_urls),"company_names":pd.Series(company_names),
                       "location1s":pd.Series(location1s),"location2s":pd.Series(location2s),
                       "ba_scores":pd.Series(ba_scores),"ba_levels":pd.Series(ba_levels),"total_ratings":pd.Series(total_ratings),
                       "beer_currents":pd.Series(beer_currents),"total_reviews":pd.Series(total_reviews)
                      })

companys.to_csv("company.csv",encoding="utf-8")
# Out:
# 13939 companies information already scraped

# %% [markdown]
# ### 4. Generate dataset summary

# %%
# Read pre-saved list of beer styles
styles=pd.read_csv("styles.csv", encoding="utf-8")
names=styles["style"]
ids=styles["id"]

# Get total beer count
count=0
top_rated=0
ratings=0
style_id=0

while style_id<len(names):
    style_name = "style_"+str(ids[style_id])+".csv"
    df=pd.read_csv(style_name, encoding="utf-8")
    count+=df.shape[0]
    ratings+=sum([locale.atoi(str(num)) for num in df["ratings"].tolist()])
    top_rated+=sum([1 for num in df["ratings"].tolist() if locale.atoi(str(num))>500])
    style_id+=1

print("Total style: {}".format(len(names)))
print("Total beer: {}".format(count))
print("Total beer with top ratings: {}".format(top_rated))
print("Total ratings: {}".format(ratings))
# Out:
# Total style: 104
# Total beer: 219064
# Total beer with top ratings: 2680
# Total ratings: 7321589

# %% [markdown]
# ### 5. Get simplified beer rating datasets

# %%
start_id=0
cut_off_num=1000

# Read pre-saved list of beer styles
styles=pd.read_csv("styles.csv", encoding="utf-8")
names=styles["style"]
ids=styles["id"]

# Create directory
folder = "C:\\Users\\yjin9\\Documents\\python-scripts\\data_incubator\\data_scraping_cleaning\\top_rated\\" 
if not os.path.exists(folder):
    os.mkdir(folder)

summary_file_path =os.path.join(folder,"beer_summary.csv")
try:
    beer_summary_df=pd.read_csv(summary_file_path,encoding="utf-8")
    beer_ids_2=beer_summary_df["beer_ids"].tolist()
    ranks=beer_summary_df["beer_ids"].tolist()
    reviews_nums=beer_summary_df["reviews_nums"].tolist()
    pDevs=beer_summary_df["pDevs"].tolist()
    bro_scores=beer_summary_df["bro_scores"].tolist()
    availabilities=beer_summary_df["availabilities"].tolist()
    ibus=beer_summary_df["ibus"].tolist()

except FileNotFoundError:
    beer_ids_2=[]
    ranks=[]
    reviews_nums=[]
    pDevs=[]
    bro_scores=[]
    availabilities=[]
    ibus=[]


### input:start_id 
for style_id in range(start_id,len(ids)):
    print("Start style id {}".format(style_id))
    t00=time()
    style_name = "style_"+str(ids[style_id])+".csv"
    df=pd.read_csv(style_name, encoding="utf-8")
    
    beer_ids = df["beer_ids"]
    beer_links=df["beer_links"]
    beer_ratings=df["ratings"]
    
    counter=0
    for beer_idx in range(len(beer_ids)):
        ### Input cut-off rating numbers, e.g. 1000
        if locale.atoi(str(beer_ratings[beer_idx]))>cut_off_num:
            counter+=1
            t0=time()
            beer_url = beer_links[beer_idx]
            beer_id = beer_ids[beer_idx]
        
            if beer_id in beer_ids_2:
                print("Beer {} already recorded".format(beer_id))
                pass
            
            else:
                print("Start record beer {}".format(beer_id))
                ## create file name for detail rating
                file_path =os.path.join(folder,"beer_"+str(beer_id)+".csv")
                ## get beer stats summary from beer page
                r = requests.get(beer_url)
                soup = BeautifulSoup(r.content,"lxml")
                
                beer_stats=soup.find_all(id="item_stats")[0].find_all("dd")
                rank=beer_stats[0].contents[0][1:]
                reviews_num=beer_stats[1].contents[0].contents[0]
                pDev=beer_stats[3].contents[0].contents[0].strip()
                bro_score=beer_stats[4].contents[0].contents[-2].contents[0]

                beer_info = soup.find_all(id="info_box")[0].contents
                try:
                    availability=beer_info[37].strip()
                except TypeError:
                    availability="N/A"

                ibu=beer_info[-7].strip()
                if ibu[-3:]!="IBU":
                    ibu="N/A"

                beer_ids_2.append(beer_id)
                ranks.append(rank)
                reviews_nums.append(reviews_num)
                pDevs.append(pDev)
                bro_scores.append(bro_score)
                availabilities.append(availability)
                ibus.append(ibu)
        
                ## get beer comments - ratings only
                user_ids=[]
                ba_scores=[]
                rDevs=[]
                looks=[]
                smells=[]
                tastes=[]
                feels=[]
                overalls=[]

                comment_end = soup.find_all(attrs={"style":"font-weight:bold;"})[0].find_all(href=re.compile("/beer/profile/"))[-1].get("href").split("=")[-1]
                comment_end = int(comment_end)

                comment_page=0
                while comment_page<=comment_end//25: 
                    comment_url =  beer_url+"?view=beer&sort=&start="+str(comment_page*25)
                    r = requests.get(comment_url)
                    soup = BeautifulSoup(r.content,"lxml")
                    comments=soup.find_all(id="rating_fullview_container")
                    for i in range(len(comments)):
                        user_id=comments[i].get("ba-user")

                        detail_rating=comments[i].find_all(id="rating_fullview_content_2")[0].contents
                        ba_score=detail_rating[0].contents[0]
                        if detail_rating[3].string==None:
                            rDev="0%"
                            by_dim_idx=4
                        else:
                            rDev=detail_rating[3].contents[0]
                            by_dim_idx=5
                        try:
                            by_dim=detail_rating[by_dim_idx].contents[0].split("|")
                            look=by_dim[0].split(":")[-1].strip()
                            smell=by_dim[1].split(":")[-1].strip()
                            taste=by_dim[2].split(":")[-1].strip()
                            feel=by_dim[3].split(":")[-1].strip()
                            overall=by_dim[4].split(":")[-1].strip()
                        except IndexError:
                            look="N/A"
                            smell="N/A"
                            taste="N/A"
                            feel="N/A"
                            overall="N/A"                 

                        user_ids.append(user_id)
                        ba_scores.append(ba_score)
                        rDevs.append(rDev)
                        looks.append(look)
                        smells.append(smell)
                        tastes.append(taste)
                        feels.append(feel)
                        overalls.append(overall)
                    comment_page+=1

                beer_df=pd.DataFrame({"user_id":pd.Series(user_ids),"ba_score":pd.Series(ba_scores),
                                      "rDev":pd.Series(rDevs),"look":pd.Series(looks),"smell":pd.Series(smells),"taste":pd.Series(tastes),
                                      "feel":pd.Series(feels),"overall":pd.Series(overalls)})
                beer_df.to_csv(file_path,encoding="utf-8")

                print("Finish beer id {}".format(beer_idx))
                print("{} sec".format(round(time()-t0)))

                beer_summary_df=pd.DataFrame({"beer_ids":pd.Series(beer_ids_2),"ranks":pd.Series(ranks),"reviews_nums":pd.Series(reviews_nums),
                                              "pDevs":pd.Series(pDevs),"bro_scores":pd.Series(bro_scores),
                                              "availabilities":pd.Series(availabilities),"ibus":pd.Series(ibus)})
                beer_summary_df.to_csv(summary_file_path,encoding="utf-8")
                
                # end if
            
            # end if
    
    print("All beers in style id {} are done".format(style_id))
    print("{} in total".format(counter))
    minutes=round((t00-time())/60)
    print("{} mins".format(minutes))
# Out:
# Start style id 0
# Beer 607 already recorded
# Beer 15881 already recorded
# Beer 35732 already recorded
# Beer 794 already recorded
# Beer 6322 already recorded
# Beer 98495 already recorded
# Beer 3711 already recorded
# Beer 35397 already recorded
# Beer 1792 already recorded
# Beer 1655 already recorded
# Beer 54522 already recorded
# Beer 1173 already recorded
# Beer 410 already recorded
# Beer 1490 already recorded
# Beer 623 already recorded
# Beer 2526 already recorded
# Beer 691 already recorded
# Beer 61877 already recorded
# Beer 363 already recorded
# Beer 2297 already recorded
# Beer 95921 already recorded
# Beer 18721 already recorded
# Beer 213 already recorded
# Beer 104466 already recorded
# Beer 199848 already recorded
# Beer 1597 already recorded
# All beers in style id 0 are done
# 26 in total
# 0 mins
# Start style id 1
# Beer 2671 already recorded
# Beer 1891 already recorded
# Beer 6533 already recorded
# Beer 20931 already recorded
# Beer 41300 already recorded
# Beer 78551 already recorded
# Beer 1009 already recorded
# Beer 4810 already recorded
# Beer 1579 already recorded
# Beer 6646 already recorded
# Beer 48224 already recorded
# Beer 34129 already recorded
# Beer 2965 already recorded
# Beer 20762 already recorded
# Beer 89499 already recorded
# All beers in style id 1 are done
# 15 in total
# 0 mins
# Start style id 2
# Beer 38470 already recorded
# Beer 79286 already recorded
# Beer 112938 already recorded
# Beer 127483 already recorded
# Beer 46070 already recorded
# Beer 67046 already recorded
# Beer 46385 already recorded
# Beer 74123 already recorded
# Beer 113859 already recorded
# Beer 58695 already recorded
# Beer 3877 already recorded
# Beer 72490 already recorded
# Beer 190513 already recorded
# All beers in style id 2 are done
# 13 in total
# 0 mins
# Start style id 3
# Beer 59987 already recorded
# Beer 22193 already recorded
# Beer 22592 already recorded
# Beer 17984 already recorded
# Beer 68008 already recorded
# All beers in style id 3 are done
# 5 in total
# 0 mins
# Start style id 4
# Beer 1161 already recorded
# Beer 33832 already recorded
# Beer 1339 already recorded
# Beer 60420 already recorded
# Beer 1924 already recorded
# Beer 2296 already recorded
# Beer 184 already recorded
# Beer 30764 already recorded
# Beer 56613 already recorded
# Beer 146 already recorded
# Beer 2894 already recorded
# Beer 28165 already recorded
# Beer 64550 already recorded
# Beer 66449 already recorded
# Beer 35134 already recorded
# Beer 3914 already recorded
# All beers in style id 4 are done
# 16 in total
# 0 mins
# Start style id 5
# All beers in style id 5 are done
# 0 in total
# 0 mins
# Start style id 6
# Beer 2093 already recorded
# Beer 7971 already recorded
# Beer 16814 already recorded
# Beer 17112 already recorded
# Beer 84596 already recorded
# Beer 74986 already recorded
# Beer 9086 already recorded
# Beer 22505 already recorded
# Beer 35738 already recorded
# Beer 99873 already recorded
# Beer 18862 already recorded
# Beer 34146 already recorded
# Beer 55939 already recorded
# Beer 1558 already recorded
# Beer 82250 already recorded
# Beer 22352 already recorded
# Beer 1372 already recorded
# Beer 117177 already recorded
# Beer 77299 already recorded
# Beer 46849 already recorded
# Beer 57908 already recorded
# Beer 17060 already recorded
# Beer 45175 already recorded
# Beer 8919 already recorded
# Beer 7597 already recorded
# Beer 52531 already recorded
# Beer 90156 already recorded
# Beer 30288 already recorded
# Beer 21690 already recorded
# Beer 28577 already recorded
# Beer 55412 already recorded
# Beer 52077 already recorded
# Beer 91670 already recorded
# Beer 57259 already recorded
# Beer 10386 already recorded
# Beer 66436 already recorded
# Beer 90410 already recorded
# Beer 22381 already recorded
# Beer 52361 already recorded
# Beer 58299 already recorded
# Beer 18421 already recorded
# Beer 34085 already recorded
# Beer 110895 already recorded
# Beer 47434 already recorded
# Beer 84045 already recorded
# Beer 77708 already recorded
# Beer 125646 already recorded
# Beer 104028 already recorded
# Beer 168971 already recorded
# Beer 22527 already recorded
# Beer 78377 already recorded
# Beer 55342 already recorded
# Beer 52928 already recorded
# Beer 47659 already recorded
# Beer 92971 already recorded
# Beer 64545 already recorded
# Beer 8037 already recorded
# Beer 115317 already recorded
# Beer 113674 already recorded
# Beer 46080 already recorded
# Beer 68269 already recorded
# Beer 78517 already recorded
# Beer 114804 already recorded
# Beer 30970 already recorded
# Beer 127652 already recorded
# Beer 123810 already recorded
# Beer 35754 already recorded
# Beer 101392 already recorded
# Beer 7284 already recorded
# Beer 31323 already recorded
# Beer 67219 already recorded
# Beer 69522 already recorded
# Beer 37966 already recorded
# Beer 113602 already recorded
# Beer 56082 already recorded
# Beer 44755 already recorded
# Beer 25851 already recorded
# Beer 92472 already recorded
# Beer 42063 already recorded
# Beer 25259 already recorded
# Beer 145496 already recorded
# Beer 178857 already recorded
# Beer 53187 already recorded
# Beer 150877 already recorded
# Beer 93219 already recorded
# Beer 99838 already recorded
# Beer 211516 already recorded
# Beer 58754 already recorded
# Beer 202078 already recorded
# Beer 36748 already recorded
# Beer 41505 already recorded
# Beer 85523 already recorded
# Beer 49838 already recorded
# Beer 28318 already recorded
# Beer 67760 already recorded
# Beer 72592 already recorded
# Beer 123062 already recorded
# Beer 90141 already recorded
# Beer 70910 already recorded
# Beer 87145 already recorded
# Beer 99011 already recorded
# Beer 140460 already recorded
# Beer 74065 already recorded
# Beer 126806 already recorded
# Beer 118987 already recorded
# Beer 12068 already recorded
# Beer 20470 already recorded
# Beer 66195 already recorded
# Beer 358 already recorded
# Beer 139515 already recorded
# Beer 169611 already recorded
# Beer 83008 already recorded
# Beer 88207 already recorded
# Beer 95230 already recorded
# Beer 101085 already recorded
# Beer 170124 already recorded
# Beer 51785 already recorded
# Beer 79405 already recorded
# Beer 119252 already recorded
# Beer 116068 already recorded
# Beer 54745 already recorded
# Beer 147173 already recorded
# Beer 130699 already recorded
# Beer 99546 already recorded
# Beer 119182 already recorded
# Beer 75933 already recorded
# Beer 138418 already recorded
# Beer 25265 already recorded
# Beer 152023 already recorded
# Beer 22172 already recorded
# Beer 27286 already recorded
# Beer 43886 already recorded
# Beer 133623 already recorded
# Beer 22484 already recorded
# Beer 62172 already recorded
# Beer 213281 already recorded
# Beer 74548 already recorded
# Beer 58467 already recorded
# All beers in style id 6 are done
# 138 in total
# 0 mins
# Start style id 7
# Beer 11757 already recorded
# Beer 19960 already recorded
# Beer 10672 already recorded
# Beer 34420 already recorded
# Beer 57747 already recorded
# Beer 3833 already recorded
# Beer 94350 already recorded
# Beer 5428 already recorded
# Beer 1013 already recorded
# Beer 47658 already recorded
# Beer 40058 already recorded
# Beer 10325 already recorded
# Beer 2392 already recorded
# Beer 37265 already recorded
# Beer 20445 already recorded
# Beer 80291 already recorded
# Beer 47022 already recorded
# Beer 51257 already recorded
# Beer 21950 already recorded
# Beer 73618 already recorded
# Beer 59151 already recorded
# Beer 42723 already recorded
# Beer 99558 already recorded
# Beer 41626 already recorded
# Beer 50176 already recorded
# Beer 46987 already recorded
# Beer 80197 already recorded
# Beer 78011 already recorded
# Beer 53728 already recorded
# Beer 76393 already recorded
# Beer 34094 already recorded
# Beer 16062 already recorded
# Beer 56469 already recorded
# Beer 56199 already recorded
# Beer 1658 already recorded
# Beer 49286 already recorded
# Beer 102340 already recorded
# Beer 31484 already recorded
# Beer 96528 already recorded
# Beer 76896 already recorded
# Beer 89345 already recorded
# Beer 81067 already recorded
# Beer 150933 already recorded
# Beer 31613 already recorded
# Beer 55063 already recorded
# Beer 115939 already recorded
# Beer 78795 already recorded
# Beer 46188 already recorded
# Beer 75218 already recorded
# Beer 37197 already recorded
# Beer 64226 already recorded
# Beer 74295 already recorded
# Beer 60694 already recorded
# Beer 137955 already recorded
# Beer 113523 already recorded
# Beer 104699 already recorded
# Beer 149331 already recorded
# Beer 67156 already recorded
# Beer 110635 already recorded
# Beer 40775 already recorded
# Beer 87246 already recorded
# Beer 109989 already recorded
# Beer 118553 already recorded
# Beer 53256 already recorded
# Beer 21100 already recorded
# Beer 76421 already recorded
# Beer 57110 already recorded
# Beer 45541 already recorded
# Beer 95746 already recorded
# Beer 78660 already recorded
# Beer 56274 already recorded
# Beer 47026 already recorded
# Beer 27339 already recorded
# Beer 139521 already recorded
# Beer 87418 already recorded
# Beer 128659 already recorded
# Beer 58811 already recorded
# Beer 221289 already recorded
# Beer 19488 already recorded
# Beer 76008 already recorded
# Beer 172669 already recorded
# Beer 98020 already recorded
# Beer 68299 already recorded
# Beer 75009 already recorded
# Beer 98050 already recorded
# Beer 136936 already recorded
# Beer 36164 already recorded
# Beer 28309 already recorded
# Beer 2812 already recorded
# Beer 37836 already recorded
# Beer 40671 already recorded
# All beers in style id 7 are done
# 91 in total
# 0 mins
# Start style id 8
# Beer 1093 already recorded
# Beer 29619 already recorded
# Beer 6108 already recorded
# Beer 88 already recorded
# Beer 30420 already recorded
# Beer 1904 already recorded
# Beer 916 already recorded
# Beer 5441 already recorded
# Beer 46363 already recorded
# Beer 2751 already recorded
# Beer 1005 already recorded
# Beer 58914 already recorded
# Beer 38180 already recorded
# Beer 89174 already recorded
# Beer 55081 already recorded
# Beer 22790 already recorded
# Beer 28203 already recorded
# Beer 6076 already recorded
# Beer 68916 already recorded
# Beer 16403 already recorded
# Beer 60330 already recorded
# Beer 76816 already recorded
# Beer 3951 already recorded
# Beer 3158 already recorded
# Beer 20478 already recorded
# Beer 27604 already recorded
# Beer 709 already recorded
# Beer 50564 already recorded
# Beer 73764 already recorded
# Beer 95386 already recorded
# Beer 3916 already recorded
# Beer 11922 already recorded
# Beer 32286 already recorded
# Beer 86237 already recorded
# Beer 57252 already recorded
# Beer 6549 already recorded
# Beer 71969 already recorded
# Beer 25755 already recorded
# Beer 111616 already recorded
# Beer 1493 already recorded
# Beer 111969 already recorded
# Beer 665 already recorded
# Beer 53886 already recorded
# Beer 15758 already recorded
# Beer 65347 already recorded
# Beer 205 already recorded
# Beer 34688 already recorded
# Beer 5385 already recorded
# Beer 148052 already recorded
# Beer 20781 already recorded
# Beer 611 already recorded
# Beer 2729 already recorded
# Beer 35626 already recorded
# Beer 55862 already recorded
# Beer 29209 already recorded
# Beer 42533 already recorded
# Beer 91677 already recorded
# Beer 58610 already recorded
# Beer 88969 already recorded
# Beer 48243 already recorded
# Beer 66674 already recorded
# Beer 9088 already recorded
# Beer 84747 already recorded
# Beer 138735 already recorded
# Beer 109789 already recorded
# Beer 62722 already recorded
# Beer 17900 already recorded
# Beer 59173 already recorded
# Beer 100443 already recorded
# Beer 176650 already recorded
# Beer 43969 already recorded
# Beer 20168 already recorded
# Beer 95068 already recorded
# Beer 76800 already recorded
# Beer 146788 already recorded
# Beer 33243 already recorded
# Beer 75898 already recorded
# Beer 46606 already recorded
# Beer 12322 already recorded
# Beer 86487 already recorded
# Beer 29127 already recorded
# Beer 39435 already recorded
# Beer 178740 already recorded
# Beer 92960 already recorded
# Beer 197183 already recorded
# Beer 69760 already recorded
# Beer 108525 already recorded
# Beer 28565 already recorded
# Beer 86106 already recorded
# Beer 89747 already recorded
# Beer 39390 already recorded
# Beer 34164 already recorded
# Beer 60832 already recorded
# Beer 53267 already recorded
# Beer 107838 already recorded
# Beer 162643 already recorded
# Beer 65038 already recorded
# Beer 27571 already recorded
# Beer 32432 already recorded
# Beer 66245 already recorded
# Beer 57223 already recorded
# Beer 62328 already recorded
# Beer 942 already recorded
# Beer 111176 already recorded
# Beer 22787 already recorded
# Beer 8411 already recorded
# Beer 1472 already recorded
# Beer 127866 already recorded
# Beer 6368 already recorded
# Beer 122334 already recorded
# Beer 81072 already recorded
# Beer 134064 already recorded
# Beer 40416 already recorded
# Beer 134098 already recorded
# Beer 9873 already recorded
# Beer 35608 already recorded
# Beer 179482 already recorded
# Beer 33215 already recorded
# Beer 88298 already recorded
# Beer 2018 already recorded
# Beer 10784 already recorded
# Beer 105430 already recorded
# Beer 42546 already recorded
# Beer 1670 already recorded
# Beer 403 already recorded
# Beer 69290 already recorded
# Beer 95114 already recorded
# Beer 5614 already recorded
# Beer 50764 already recorded
# Beer 118971 already recorded
# Beer 118865 already recorded
# Beer 31763 already recorded
# Beer 5554 already recorded
# Beer 150209 already recorded
# Beer 74530 already recorded
# Beer 112128 already recorded
# Beer 40628 already recorded
# Beer 33467 already recorded
# Beer 49058 already recorded
# Beer 52766 already recorded
# Beer 125926 already recorded
# Beer 128182 already recorded
# Beer 65842 already recorded
# Beer 466 already recorded
# Beer 89586 already recorded
# Beer 17492 already recorded
# Beer 96304 already recorded
# Beer 65993 already recorded
# Beer 52718 already recorded
# Beer 62129 already recorded
# Beer 73173 already recorded
# Beer 78791 already recorded
# Beer 144097 already recorded
# Beer 59815 already recorded
# All beers in style id 8 are done
# 154 in total
# 0 mins
# Start style id 9
# Beer 276 already recorded
# Beer 64228 already recorded
# Beer 6518 already recorded
# Beer 39 already recorded
# Beer 72170 already recorded
# Beer 195 already recorded
# Beer 48582 already recorded
# Beer 751 already recorded
# Beer 78906 already recorded
# Beer 225 already recorded
# Beer 51512 already recorded
# Beer 4073 already recorded
# Beer 57886 already recorded
# Beer 55564 already recorded
# Beer 56738 already recorded
# Beer 66281 already recorded
# Beer 133621 already recorded
# Beer 5753 already recorded
# Beer 1213 already recorded
# Beer 98383 already recorded
# Beer 1158 already recorded
# Beer 88949 already recorded
# Beer 6590 already recorded
# Beer 5643 already recorded
# Beer 44896 already recorded
# Beer 5948 already recorded
# Beer 91358 already recorded
# Beer 110744 already recorded
# Beer 107406 already recorded
# Beer 88404 already recorded
# Beer 86647 already recorded
# Beer 26233 already recorded
# Beer 116067 already recorded
# Beer 20536 already recorded
# Beer 175577 already recorded
# Beer 100217 already recorded
# Beer 26395 already recorded
# Beer 155168 already recorded
# Beer 914 already recorded
# Beer 74467 already recorded
# Beer 77648 already recorded
# Beer 113339 already recorded
# Beer 55987 already recorded
# Beer 78937 already recorded
# Beer 154542 already recorded
# Beer 165463 already recorded
# Beer 50241 already recorded
# Beer 3451 already recorded
# Beer 94175 already recorded
# Beer 105399 already recorded
# Beer 2094 already recorded
# Beer 114532 already recorded
# Beer 77480 already recorded
# Beer 114884 already recorded
# Beer 30679 already recorded
# Beer 59672 already recorded
# Beer 3714 already recorded
# All beers in style id 9 are done
# 57 in total
# 0 mins
# Start style id 10
# Beer 49789 already recorded
# Beer 1094 already recorded
# Beer 9478 already recorded
# Beer 103 already recorded
# Beer 17141 already recorded
# Beer 49092 already recorded
# Beer 1260 already recorded
# Beer 28536 already recorded
# Beer 65113 already recorded
# Beer 318 already recorded
# Beer 17497 already recorded
# Beer 2550 already recorded
# Beer 96436 already recorded
# Beer 52633 already recorded
# Beer 70089 already recorded
# Beer 36594 already recorded
# All beers in style id 10 are done
# 16 in total
# 0 mins
# Start style id 11
# Beer 7348 already recorded
# Beer 48505 already recorded
# Beer 226 already recorded
# Beer 198 already recorded
# Beer 27800 already recorded
# Beer 61 already recorded
# Beer 279 already recorded
# Beer 1287 already recorded
# Beer 353 already recorded
# Beer 622 already recorded
# Beer 61062 already recorded
# Beer 88269 already recorded
# Beer 20564 already recorded
# Beer 37795 already recorded
# Beer 7438 already recorded
# Beer 1769 already recorded
# Beer 62761 already recorded
# Beer 75446 already recorded
# Beer 33183 already recorded
# Beer 101458 already recorded
# Beer 86776 already recorded
# Beer 33336 already recorded
# Beer 90473 already recorded
# Beer 87109 already recorded
# Beer 85822 already recorded
# Beer 6088 already recorded
# Beer 84140 already recorded
# Beer 172420 already recorded
# Beer 738 already recorded
# Beer 75502 already recorded
# Beer 12104 already recorded
# Beer 62972 already recorded
# Beer 85 already recorded
# Beer 921 already recorded
# Beer 132105 already recorded
# Beer 77563 already recorded
# Beer 5703 already recorded
# Beer 5722 already recorded
# Beer 10433 already recorded
# All beers in style id 11 are done
# 39 in total
# 0 mins
# Start style id 12
# Beer 1117 already recorded
# Beer 1118 already recorded
# Beer 197 already recorded
# Beer 2403 already recorded
# Beer 283 already recorded
# Beer 1153 already recorded
# Beer 2010 already recorded
# Beer 2511 already recorded
# Beer 56545 already recorded
# Beer 6227 already recorded
# Beer 10330 already recorded
# Beer 86545 already recorded
# Beer 1192 already recorded
# Beer 1830 already recorded
# Beer 135684 already recorded
# Beer 6373 already recorded
# Beer 2870 already recorded
# Beer 2810 already recorded
# All beers in style id 12 are done
# 18 in total
# 0 mins
# Start style id 13
# Beer 92 already recorded
# Beer 1056 already recorded
# Beer 2264 already recorded
# Beer 8951 already recorded
# Beer 48385 already recorded
# Beer 2533 already recorded
# Beer 25759 already recorded
# Beer 62645 already recorded
# Beer 60886 already recorded
# Beer 47954 already recorded
# Beer 32413 already recorded
# Beer 459 already recorded
# Beer 142974 already recorded
# Beer 41043 already recorded
# Beer 55401 already recorded
# All beers in style id 13 are done
# 15 in total
# 0 mins
# Start style id 14
# Beer 22227 already recorded
# Beer 45653 already recorded
# Beer 9474 already recorded
# Beer 20518 already recorded
# Beer 27992 already recorded
# Beer 51741 already recorded
# Beer 70286 already recorded
# Beer 26541 already recorded
# Beer 53747 already recorded
# Beer 19314 already recorded
# Beer 94634 already recorded
# Beer 56266 already recorded
# Beer 42203 already recorded
# Beer 45368 already recorded
# Beer 34315 already recorded
# Beer 63724 already recorded
# Beer 55992 already recorded
# Beer 97036 already recorded
# Beer 84772 already recorded
# Beer 62403 already recorded
# Beer 90250 already recorded
# Beer 43217 already recorded
# Beer 66743 already recorded
# Beer 38149 already recorded
# Beer 79533 already recorded
# All beers in style id 14 are done
# 25 in total
# 0 mins
# Start style id 15
# Beer 1381 already recorded
# Beer 1741 already recorded
# All beers in style id 15 are done
# 2 in total
# 0 mins
# Start style id 16
# Beer 41702 already recorded
# Beer 354 already recorded
# Beer 77601 already recorded
# All beers in style id 16 are done
# 3 in total
# 0 mins
# Start style id 17
# Beer 1963 already recorded
# Beer 23506 already recorded
# Beer 1376 already recorded
# Beer 169625 already recorded
# All beers in style id 17 are done
# 4 in total
# 0 mins
# Start style id 18
# Beer 38394 already recorded
# Beer 6260 already recorded
# Beer 100 already recorded
# Beer 25880 already recorded
# Beer 1932 already recorded
# Beer 45844 already recorded
# Beer 32767 already recorded
# Beer 74 already recorded
# Beer 11819 already recorded
# Beer 52248 already recorded
# Beer 1567 already recorded
# Beer 97291 already recorded
# Beer 62449 already recorded
# Beer 47020 already recorded
# Beer 73731 already recorded
# Beer 7077 already recorded
# Beer 72412 already recorded
# Beer 643 already recorded
# Beer 25608 already recorded
# Beer 33405 already recorded
# Beer 71325 already recorded
# All beers in style id 18 are done
# 21 in total
# 0 mins
# Start style id 19
# Beer 16074 already recorded
# Beer 43223 already recorded
# Beer 56168 already recorded
# Beer 30502 already recorded
# Beer 16115 already recorded
# All beers in style id 19 are done
# 5 in total
# 0 mins
# Start style id 20
# Beer 51069 already recorded
# Beer 84078 already recorded
# Beer 105784 already recorded
# All beers in style id 20 are done
# 3 in total
# 0 mins
# Start style id 21
# Beer 1862 already recorded
# Beer 38818 already recorded
# All beers in style id 21 are done
# 2 in total
# 0 mins
# Start style id 22
# Beer 52855 already recorded
# Beer 57912 already recorded
# Beer 43905 already recorded
# Beer 27804 already recorded
# Beer 36727 already recorded
# Beer 68942 already recorded
# Beer 99699 already recorded
# Beer 113857 already recorded
# Beer 72465 already recorded
# All beers in style id 22 are done
# 9 in total
# 0 mins
# Start style id 23
# Beer 129 already recorded
# Beer 2137 already recorded
# Beer 593 already recorded
# Beer 2184 already recorded
# Beer 13741 already recorded
# Beer 56875 already recorded
# Beer 620 already recorded
# Beer 77233 already recorded
# Beer 108956 already recorded
# Beer 2823 already recorded
# Beer 92397 already recorded
# All beers in style id 23 are done
# 11 in total
# 0 mins
# Start style id 24
# Beer 2512 already recorded
# Beer 1696 already recorded
# Beer 30 already recorded
# Beer 33 already recorded
# Beer 1180 already recorded
# Beer 155 already recorded
# Beer 7531 already recorded
# Beer 30282 already recorded
# Beer 1421 already recorded
# Beer 40051 already recorded
# Beer 3635 already recorded
# Beer 2347 already recorded
# Beer 6947 already recorded
# Beer 34877 already recorded
# Beer 3089 already recorded
# Beer 47678 already recorded
# Beer 52510 already recorded
# Beer 2269 already recorded
# Beer 13742 already recorded
# Beer 140 already recorded
# Beer 21363 already recorded
# Beer 76874 already recorded
# Beer 1581 already recorded
# Beer 51619 already recorded
# Beer 71947 already recorded
# Beer 39267 already recorded
# Beer 813 already recorded
# All beers in style id 24 are done
# 27 in total
# 0 mins
# Start style id 25
# Beer 695 already recorded
# Beer 1385 already recorded
# Beer 4318 already recorded
# Beer 12770 already recorded
# Beer 411 already recorded
# Beer 694 already recorded
# Beer 1836 already recorded
# Beer 156 already recorded
# Beer 35328 already recorded
# Beer 53134 already recorded
# Beer 635 already recorded
# Beer 65200 already recorded
# Beer 817 already recorded
# Beer 2361 already recorded
# All beers in style id 25 are done
# 14 in total
# 0 mins
# Start style id 26
# All beers in style id 26 are done
# 0 in total
# 0 mins
# Start style id 27
# Beer 18975 already recorded
# Beer 2961 already recorded
# Beer 30955 already recorded
# All beers in style id 27 are done
# 3 in total
# 0 mins
# Start style id 28
# Beer 672 already recorded
# Beer 142 already recorded
# Beer 674 already recorded
# Beer 3842 already recorded
# Beer 1855 already recorded
# Beer 16807 already recorded
# Beer 1912 already recorded
# Beer 857 already recorded
# Beer 10 already recorded
# Beer 1856 already recorded
# Beer 20604 already recorded
# Beer 2508 already recorded
# Beer 138 already recorded
# Beer 26667 already recorded
# Beer 1496 already recorded
# All beers in style id 28 are done
# 15 in total
# 0 mins
# Start style id 29
# Beer 7712 already recorded
# All beers in style id 29 are done
# 1 in total
# 0 mins
# Start style id 30
# Beer 1917 already recorded
# Beer 10482 already recorded
# Beer 44409 already recorded
# Beer 23459 already recorded
# Beer 773 already recorded
# Beer 51983 already recorded
# Beer 2479 already recorded
# All beers in style id 30 are done
# 7 in total
# 0 mins
# Start style id 31
# Beer 1745 already recorded
# Beer 673 already recorded
# Beer 50772 already recorded
# Beer 54888 already recorded
# Beer 38530 already recorded
# Beer 1882 already recorded
# Beer 74778 already recorded
# Beer 42193 already recorded
# All beers in style id 31 are done
# 8 in total
# 0 mins
# Start style id 32
# Beer 1703 already recorded
# Beer 6305 already recorded
# Beer 6104 already recorded
# Beer 70745 already recorded
# Beer 51116 already recorded
# Beer 86970 already recorded
# Beer 1710 already recorded
# Beer 21683 already recorded
# Beer 6317 already recorded
# Beer 13826 already recorded
# Beer 5357 already recorded
# Beer 79387 already recorded
# Beer 5212 already recorded
# Beer 2595 already recorded
# All beers in style id 32 are done
# 14 in total
# 0 mins
# Start style id 33
# Beer 5281 already recorded
# Beer 599 already recorded
# Beer 1632 already recorded
# Beer 2557 already recorded
# Beer 8954 already recorded
# Beer 3659 already recorded
# Beer 2558 already recorded
# Beer 13825 already recorded
# Beer 600 already recorded
# Beer 6306 already recorded
# Beer 598 already recorded
# Beer 85743 already recorded
# All beers in style id 33 are done
# 12 in total
# 0 mins
# Start style id 34
# Beer 7435 already recorded
# All beers in style id 34 are done
# 1 in total
# 0 mins
# Start style id 35
# Beer 1708 already recorded
# Beer 645 already recorded
# Beer 3457 already recorded
# Beer 1545 already recorded
# Beer 39621 already recorded
# Beer 63249 already recorded
# Beer 43670 already recorded
# Beer 34306 already recorded
# Beer 1402 already recorded
# Beer 39286 already recorded
# Beer 2014 already recorded
# Beer 8998 already recorded
# Beer 71973 already recorded
# Beer 34312 already recorded
# Beer 1635 already recorded
# Beer 34415 already recorded
# Beer 89540 already recorded
# All beers in style id 35 are done
# 17 in total
# 0 mins
# Start style id 36
# Beer 141 already recorded
# Beer 50570 already recorded
# Beer 48824 already recorded
# Beer 1717 already recorded
# Beer 36333 already recorded
# Beer 51480 already recorded
# Beer 5057 already recorded
# Beer 62282 already recorded
# Beer 42434 already recorded
# Beer 57202 already recorded
# Beer 49374 already recorded
# Beer 60785 already recorded
# Beer 64916 already recorded
# Beer 66507 already recorded
# Beer 69702 already recorded
# Beer 30845 already recorded
# Beer 114806 already recorded
# Beer 1716 already recorded
# Beer 27837 already recorded
# Beer 28176 already recorded
# Beer 88169 already recorded
# Beer 81079 already recorded
# Beer 37112 already recorded
# Beer 58048 already recorded
# Beer 90101 already recorded
# Beer 118062 already recorded
# Beer 58523 already recorded
# Beer 46983 already recorded
# Beer 93400 already recorded
# Beer 88209 already recorded
# Beer 108002 already recorded
# Beer 4629 already recorded
# Beer 47776 already recorded
# Beer 61139 already recorded
# Beer 32423 already recorded
# All beers in style id 36 are done
# 35 in total
# 0 mins
# Start style id 37
# Beer 34 already recorded
# Beer 1003 already recorded
# Beer 646 already recorded
# Beer 1346 already recorded
# Beer 656 already recorded
# Beer 16909 already recorded
# Beer 722 already recorded
# Beer 1054 already recorded
# Beer 448 already recorded
# Beer 6073 already recorded
# Beer 2566 already recorded
# Beer 39754 already recorded
# Beer 42878 already recorded
# Beer 53773 already recorded
# Beer 658 already recorded
# All beers in style id 37 are done
# 15 in total
# 0 mins
# Start style id 38
# Beer 1212 already recorded
# Beer 59 already recorded
# Beer 248 already recorded
# Beer 39908 already recorded
# Beer 53453 already recorded
# Beer 9689 already recorded
# Beer 31 already recorded
# Beer 29015 already recorded
# Beer 8682 already recorded
# Beer 109458 already recorded
# Beer 16506 already recorded
# Beer 32435 already recorded
# Beer 86393 already recorded
# Beer 47364 already recorded
# Beer 7879 already recorded
# Beer 2013 already recorded
# Beer 69218 already recorded
# Beer 8297 already recorded
# Beer 48933 already recorded
# Beer 47317 already recorded
# Beer 58609 already recorded
# Beer 9755 already recorded
# Beer 76781 already recorded
# Beer 9353 already recorded
# Beer 78 already recorded
# Beer 19306 already recorded
# All beers in style id 38 are done
# 26 in total
# 0 mins
# Start style id 39
# Beer 24071 already recorded
# Beer 79898 already recorded
# Beer 40674 already recorded
# Beer 88889 already recorded
# Beer 65809 already recorded
# All beers in style id 39 are done
# 5 in total
# 0 mins
# Start style id 40
# All beers in style id 40 are done
# 0 in total
# 0 mins
# Start style id 41
# Beer 100421 already recorded
# Beer 41121 already recorded
# Beer 18199 already recorded
# Beer 1566 already recorded
# Beer 46230 already recorded
# Beer 1445 already recorded
# Beer 50509 already recorded
# Beer 49472 already recorded
# Beer 705 already recorded
# Beer 18093 already recorded
# Beer 2678 already recorded
# All beers in style id 41 are done
# 11 in total
# 0 mins
# Start style id 42
# Beer 1157 already recorded
# All beers in style id 42 are done
# 1 in total
# 0 mins
# Start style id 43
# Beer 639 already recorded
# Beer 576 already recorded
# Beer 6 already recorded
# Beer 47731 already recorded
# Beer 22343 already recorded
# Beer 9900 already recorded
# Beer 50082 already recorded
# Beer 1169 already recorded
# All beers in style id 43 are done
# 8 in total
# 0 mins
# Start style id 44
# Beer 46504 already recorded
# All beers in style id 44 are done
# 1 in total
# 0 mins
# Start style id 45
# Beer 3968 already recorded
# Beer 311 already recorded
# Beer 1575 already recorded
# Beer 147 already recorded
# Beer 361 already recorded
# Beer 573 already recorded
# Beer 41716 already recorded
# Beer 298 already recorded
# Beer 270 already recorded
# Beer 80735 already recorded
# Beer 693 already recorded
# All beers in style id 45 are done
# 11 in total
# 0 mins
# Start style id 46
# Beer 1798 already recorded
# Beer 5653 already recorded
# Beer 811 already recorded
# Beer 222 already recorded
# Beer 637 already recorded
# Beer 1193 already recorded
# Beer 32631 already recorded
# Beer 575 already recorded
# Beer 186 already recorded
# Beer 159 already recorded
# Beer 1374 already recorded
# Beer 1439 already recorded
# Beer 3824 already recorded
# All beers in style id 46 are done
# 13 in total
# 0 mins
# Start style id 47
# All beers in style id 47 are done
# 0 in total
# 0 mins
# Start style id 48
# Beer 572 already recorded
# Beer 221 already recorded
# Beer 116648 already recorded
# Beer 875 already recorded
# Beer 1251 already recorded
# Beer 1262 already recorded
# Beer 55861 already recorded
# All beers in style id 48 are done
# 7 in total
# 0 mins
# Start style id 49
# Beer 86189 already recorded
# Beer 297 already recorded
# Beer 75364 already recorded
# All beers in style id 49 are done
# 3 in total
# 0 mins
# Start style id 50
# Beer 18698 already recorded
# Beer 199 already recorded
# Beer 560 already recorded
# All beers in style id 50 are done
# 3 in total
# 0 mins
# Start style id 51
# Beer 219 already recorded
# Beer 236 already recorded
# Beer 1543 already recorded
# Beer 1119 already recorded
# Beer 13637 already recorded
# Beer 26542 already recorded
# Beer 15989 already recorded
# All beers in style id 51 are done
# 7 in total
# 0 mins
# Start style id 52
# Beer 752 already recorded
# Beer 1115 already recorded
# Beer 69792 already recorded
# Beer 54076 already recorded
# All beers in style id 52 are done
# 4 in total
# 0 mins
# Start style id 53
# Beer 3434 already recorded
# Beer 73 already recorded
# Beer 43687 already recorded
# Beer 128500 already recorded
# Beer 115076 already recorded
# Beer 1879 already recorded
# Beer 62984 already recorded
# Beer 124424 already recorded
# Beer 76440 already recorded
# Beer 20216 already recorded
# Beer 25435 already recorded
# Beer 54413 already recorded
# Beer 76086 already recorded
# Beer 105725 already recorded
# Beer 3960 already recorded
# Beer 6903 already recorded
# Beer 2442 already recorded
# Beer 97563 already recorded
# All beers in style id 53 are done
# 18 in total
# 0 mins
# Start style id 54
# Beer 571 already recorded
# Beer 56973 already recorded
# Beer 45897 already recorded
# Beer 615 already recorded
# Beer 28877 already recorded
# Beer 46021 already recorded
# Beer 8322 already recorded
# Beer 52128 already recorded
# Beer 2354 already recorded
# Beer 20539 already recorded
# Beer 2704 already recorded
# Beer 95930 already recorded
# Beer 16079 already recorded
# Beer 5045 already recorded
# Beer 5490 already recorded
# All beers in style id 54 are done
# 15 in total
# 0 mins
# Start style id 55
# Beer 24905 already recorded
# Beer 1867 already recorded
# Beer 1446 already recorded
# Beer 945 already recorded
# Beer 34313 already recorded
# Beer 3295 already recorded
# Beer 14368 already recorded
# Beer 19426 already recorded
# Beer 37113 already recorded
# Beer 18850 already recorded
# Beer 926 already recorded
# All beers in style id 55 are done
# 11 in total
# 0 mins
# Start style id 56
# Beer 412 already recorded
# Beer 34483 already recorded
# Beer 21822 already recorded
# Beer 680 already recorded
# Beer 41815 already recorded
# Beer 1444 already recorded
# Beer 12013 already recorded
# Beer 86149 already recorded
# Beer 19216 already recorded
# Beer 7520 already recorded
# Beer 45073 already recorded
# Beer 33127 already recorded
# Beer 782 already recorded
# Beer 15813 already recorded
# Beer 60426 already recorded
# Beer 45973 already recorded
# Beer 33644 already recorded
# Beer 40149 already recorded
# Beer 47695 already recorded
# Beer 1373 already recorded
# Beer 8023 already recorded
# Beer 88880 already recorded
# Beer 27143 already recorded
# Beer 189272 already recorded
# Beer 38334 already recorded
# Beer 73427 already recorded
# Beer 42349 already recorded
# Beer 34203 already recorded
# Beer 47360 already recorded
# Beer 19667 already recorded
# Beer 35284 already recorded
# Beer 34484 already recorded
# Beer 356 already recorded
# Beer 52752 already recorded
# Beer 51153 already recorded
# Beer 185 already recorded
# Beer 111538 already recorded
# Beer 67722 already recorded
# Beer 31548 already recorded
# Beer 68680 already recorded
# Beer 33894 already recorded
# All beers in style id 56 are done
# 41 in total
# 0 mins
# Start style id 57
# Beer 1881 already recorded
# Beer 1576 already recorded
# Beer 2178 already recorded
# Beer 577 already recorded
# Beer 2081 already recorded
# Beer 310 already recorded
# Beer 62732 already recorded
# Beer 3508 already recorded
# All beers in style id 57 are done
# 8 in total
# 0 mins
# Start style id 58
# Beer 45086 already recorded
# All beers in style id 58 are done
# 1 in total
# 0 mins
# Start style id 59
# Beer 1309 already recorded
# Beer 273 already recorded
# Beer 3128 already recorded
# All beers in style id 59 are done
# 3 in total
# 0 mins
# Start style id 60
# Beer 35720 already recorded
# Beer 43889 already recorded
# Beer 43456 already recorded
# Beer 36378 already recorded
# Beer 90585 already recorded
# All beers in style id 60 are done
# 5 in total
# 0 mins
# Start style id 61
# Beer 808 already recorded
# Beer 924 already recorded
# Beer 45591 already recorded
# Beer 2041 already recorded
# Beer 135 already recorded
# All beers in style id 61 are done
# 5 in total
# 0 mins
# Start style id 62
# Beer 81010 already recorded
# Beer 99790 already recorded
# Beer 132073 already recorded
# Beer 187317 already recorded
# Beer 121506 already recorded
# Beer 156202 already recorded
# Beer 95326 already recorded
# Beer 10683 already recorded
# All beers in style id 62 are done
# 8 in total
# 0 mins
# Start style id 63
# Beer 731 already recorded
# Beer 1946 already recorded
# Beer 48434 already recorded
# Beer 1256 already recorded
# Beer 132 already recorded
# Beer 17 already recorded
# Beer 2434 already recorded
# Beer 18305 already recorded
# Beer 3280 already recorded
# Beer 772 already recorded
# Beer 1062 already recorded
# Beer 2249 already recorded
# Beer 37586 already recorded
# Beer 3836 already recorded
# Beer 1552 already recorded
# Beer 759 already recorded
# All beers in style id 63 are done
# 16 in total
# 0 mins
# Start style id 64
# Beer 1171 already recorded
# Beer 696 already recorded
# Beer 2040 already recorded
# Beer 307 already recorded
# All beers in style id 64 are done
# 4 in total
# 0 mins
# Start style id 65
# Beer 760 already recorded
# Beer 2958 already recorded
# All beers in style id 65 are done
# 2 in total
# 0 mins
# Start style id 66
# All beers in style id 66 are done
# 0 in total
# 0 mins
# Start style id 67
# Beer 224 already recorded
# Beer 35625 already recorded
# Beer 1008 already recorded
# Beer 37774 already recorded
# All beers in style id 67 are done
# 4 in total
# 0 mins
# Start style id 68
# Beer 754 already recorded
# Beer 650 already recorded
# Beer 703 already recorded
# Beer 408 already recorded
# Beer 3338 already recorded
# All beers in style id 68 are done
# 5 in total
# 0 mins
# Start style id 69
# Beer 29602 already recorded
# Beer 38365 already recorded
# Beer 5096 already recorded
# All beers in style id 69 are done
# 3 in total
# 0 mins
# Start style id 70
# All beers in style id 70 are done
# 0 in total
# 0 mins
# Start style id 71
# Beer 35036 already recorded
# Beer 7463 already recorded
# Beer 14712 already recorded
# Beer 402 already recorded
# Beer 28039 already recorded
# Beer 45765 already recorded
# Beer 94714 already recorded
# Beer 47440 already recorded
# Beer 39258 already recorded
# Beer 16400 already recorded
# Beer 846 already recorded
# Beer 118299 already recorded
# Beer 36 already recorded
# Beer 79 already recorded
# Beer 96677 already recorded
# All beers in style id 71 are done
# 15 in total
# 0 mins
# Start style id 72
# Beer 1159 already recorded
# Beer 1163 already recorded
# Beer 12719 already recorded
# Beer 740 already recorded
# Beer 34069 already recorded
# All beers in style id 72 are done
# 5 in total
# 0 mins
# Start style id 73
# Beer 245 already recorded
# All beers in style id 73 are done
# 1 in total
# 0 mins
# Start style id 74
# Beer 65 already recorded
# Beer 1331 already recorded
# Beer 232 already recorded
# Beer 580 already recorded
# Beer 689 already recorded
# Beer 1276 already recorded
# Beer 567 already recorded
# Beer 1907 already recorded
# Beer 2280 already recorded
# Beer 1321 already recorded
# Beer 1371 already recorded
# Beer 918 already recorded
# Beer 848 already recorded
# Beer 2755 already recorded
# Beer 34804 already recorded
# Beer 1312 already recorded
# Beer 670 already recorded
# Beer 653 already recorded
# Beer 2803 already recorded
# Beer 1053 already recorded
# Beer 7406 already recorded
# Beer 1299 already recorded
# Beer 1642 already recorded
# Beer 2176 already recorded
# All beers in style id 74 are done
# 24 in total
# 0 mins
# Start style id 75
# Beer 1351 already recorded
# Beer 148 already recorded
# Beer 909 already recorded
# Beer 2318 already recorded
# Beer 832 already recorded
# Beer 87749 already recorded
# Beer 88582 already recorded
# All beers in style id 75 are done
# 7 in total
# 0 mins
# Start style id 76
# Beer 60078 already recorded
# Beer 99033 already recorded
# Beer 75414 already recorded
# Beer 43738 already recorded
# Beer 16471 already recorded
# Beer 51557 already recorded
# All beers in style id 76 are done
# 6 in total
# 0 mins
# Start style id 77
# Beer 810 already recorded
# Beer 718 already recorded
# Beer 3350 already recorded
# All beers in style id 77 are done
# 3 in total
# 0 mins
# Start style id 78
# Beer 5328 already recorded
# Beer 71820 already recorded
# Beer 10071 already recorded
# Beer 1249 already recorded
# Beer 88429 already recorded
# Beer 79373 already recorded
# Beer 90090 already recorded
# Beer 23713 already recorded
# Beer 130301 already recorded
# Beer 6228 already recorded
# Beer 7313 already recorded
# All beers in style id 78 are done
# 11 in total
# 0 mins
# Start style id 79
# Beer 63 already recorded
# All beers in style id 79 are done
# 1 in total
# 0 mins
# Start style id 80
# Beer 1320 already recorded
# Beer 837 already recorded
# Beer 332 already recorded
# Beer 41821 already recorded
# Beer 3734 already recorded
# Beer 1503 already recorded
# Beer 1524 already recorded
# Beer 1341 already recorded
# Beer 233 already recorded
# Beer 76899 already recorded
# Beer 1390 already recorded
# Beer 436 already recorded
# Beer 20732 already recorded
# Beer 3347 already recorded
# All beers in style id 80 are done
# 14 in total
# 0 mins
# Start style id 81
# All beers in style id 81 are done
# 0 in total
# 0 mins
# Start style id 82
# Beer 3558 already recorded
# Beer 429 already recorded
# Beer 48139 already recorded
# Beer 19589 already recorded
# Beer 6715 already recorded
# Beer 98220 already recorded
# Beer 933 already recorded
# Beer 33245 already recorded
# All beers in style id 82 are done
# 8 in total
# 0 mins
# Start style id 83
# Beer 1914 already recorded
# Beer 57285 already recorded
# All beers in style id 83 are done
# 2 in total
# 0 mins
# Start style id 84
# Beer 449 already recorded
# Beer 246 already recorded
# Beer 862 already recorded
# Beer 1790 already recorded
# Beer 1426 already recorded
# Beer 767 already recorded
# Beer 2270 already recorded
# Beer 3970 already recorded
# Beer 867 already recorded
# Beer 976 already recorded
# Beer 778 already recorded
# All beers in style id 84 are done
# 11 in total
# 0 mins
# Start style id 85
# All beers in style id 85 are done
# 0 in total
# 0 mins
# Start style id 86
# Beer 101 already recorded
# Beer 1352 already recorded
# Beer 14309 already recorded
# Beer 1252 already recorded
# All beers in style id 86 are done
# 4 in total
# 0 mins
# Start style id 87
# Beer 131 already recorded
# Beer 4109 already recorded
# Beer 99 already recorded
# Beer 387 already recorded
# Beer 779 already recorded
# Beer 776 already recorded
# Beer 47785 already recorded
# Beer 2732 already recorded
# Beer 2899 already recorded
# Beer 39129 already recorded
# Beer 871 already recorded
# All beers in style id 87 are done
# 11 in total
# 0 mins
# Start style id 88
# Beer 228 already recorded
# Beer 50443 already recorded
# Beer 133 already recorded
# All beers in style id 88 are done
# 3 in total
# 0 mins
# Start style id 89
# Beer 1934 already recorded
# Beer 11784 already recorded
# Beer 11582 already recorded
# All beers in style id 89 are done
# 3 in total
# 0 mins
# Start style id 90
# Beer 1010 already recorded
# Beer 54904 already recorded
# Beer 2435 already recorded
# Beer 935 already recorded
# Beer 83473 already recorded
# Beer 409 already recorded
# Beer 1641 already recorded
# Beer 62989 already recorded
# Beer 4108 already recorded
# Beer 144200 already recorded
# Beer 1283 already recorded
# Beer 24651 already recorded
# Beer 700 already recorded
# Beer 799 already recorded
# Beer 788 already recorded
# All beers in style id 90 are done
# 15 in total
# 0 mins
# Start style id 91
# All beers in style id 91 are done
# 0 in total
# 0 mins
# Start style id 92
# Beer 355 already recorded
# Beer 1565 already recorded
# All beers in style id 92 are done
# 2 in total
# 0 mins
# Start style id 93
# Beer 102 already recorded
# Beer 1361 already recorded
# Beer 582 already recorded
# Beer 386 already recorded
# Beer 13896 already recorded
# Beer 1017 already recorded
# Beer 234 already recorded
# Beer 5757 already recorded
# Beer 570 already recorded
# Beer 6861 already recorded
# Beer 2011 already recorded
# Beer 32410 already recorded
# Beer 313 already recorded
# Beer 60642 already recorded
# Beer 32695 already recorded
# Beer 6075 already recorded
# Beer 51631 already recorded
# Beer 19651 already recorded
# All beers in style id 93 are done
# 18 in total
# 0 mins
# Start style id 94
# Beer 1611 already recorded
# Beer 8116 already recorded
# Beer 134 already recorded
# All beers in style id 94 are done
# 3 in total
# 0 mins
# Start style id 95
# Beer 712 already recorded
# Beer 3062 already recorded
# Beer 57471 already recorded
# Beer 1944 already recorded
# Beer 44531 already recorded
# Beer 388 already recorded
# All beers in style id 95 are done
# 6 in total
# 0 mins
# Start style id 96
# Beer 727 already recorded
# Beer 1324 already recorded
# Beer 71501 already recorded
# All beers in style id 96 are done
# 3 in total
# 0 mins
# Start style id 97
# Beer 21300 already recorded
# Beer 1774 already recorded
# Beer 32575 already recorded
# Beer 1314 already recorded
# Beer 73965 already recorded
# Beer 321 already recorded
# All beers in style id 97 are done
# 6 in total
# 0 mins
# Start style id 98
# Beer 104 already recorded
# Beer 667 already recorded
# Beer 229 already recorded
# Beer 171 already recorded
# Beer 5 already recorded
# All beers in style id 98 are done
# 5 in total
# 0 mins
# Start style id 99
# All beers in style id 99 are done
# 0 in total
# 0 mins
# Start style id 100
# Beer 2779 already recorded
# All beers in style id 100 are done
# 1 in total
# 0 mins
# Start style id 101
# Beer 299 already recorded
# Beer 108 already recorded
# Beer 1585 already recorded
# Beer 36010 already recorded
# Beer 1577 already recorded
# Beer 23474 already recorded
# Beer 7 already recorded
# Beer 5488 already recorded
# Beer 86172 already recorded
# Beer 4202 already recorded
# Beer 25852 already recorded
# Beer 3523 already recorded
# Beer 44932 already recorded
# Beer 26049 already recorded
# Beer 20014 already recorded
# Beer 32437 already recorded
# Beer 81388 already recorded
# Beer 96814 already recorded
# Beer 48911 already recorded
# Beer 96831 already recorded
# Beer 1903 already recorded
# Beer 23505 already recorded
# Beer 2967 already recorded
# Beer 70602 already recorded
# Beer 21466 already recorded
# Beer 67274 already recorded
# Beer 18021 already recorded
# Beer 1971 already recorded
# Beer 25649 already recorded
# Beer 62866 already recorded
# Beer 38795 already recorded
# Beer 87280 already recorded
# Beer 67238 already recorded
# All beers in style id 101 are done
# 33 in total
# 0 mins
# Start style id 102
# Beer 1587 already recorded
# Beer 86621 already recorded
# Beer 86626 already recorded
# Beer 24259 already recorded
# Beer 702 already recorded
# Beer 1876 already recorded
# Beer 40702 already recorded
# All beers in style id 102 are done
# 7 in total
# 0 mins
# Start style id 103
# Beer 90 already recorded
# Beer 36707 already recorded
# Beer 7697 already recorded
# All beers in style id 103 are done
# 3 in total
# 0 mins

# %% [markdown]
# ### 6. Scrape simplified user info

# %%
folder = "C:\\Users\\yjin9\\Documents\\python-scripts\\data_incubator\\data_scraping_cleaning\\top_rated\\" 

summary_file_path =os.path.join(folder,"beer_summary"+".csv")
beer_ids=pd.read_csv(summary_file_path,encoding="utf-8")["beer_ids"].tolist()

total_user_ids=[]

for beer_idx in range(len(beer_ids)):
    file_path =os.path.join(folder,"beer_"+str(beer_ids[beer_idx])+".csv")
    user_ids=pd.read_csv(file_path,encoding="utf-8")["user_id"].tolist()
    user_ids=[str(int(i)) for i in user_ids if not np.isnan(i)]
    total_user_ids=total_user_ids+user_ids

unique_user_ids=set(total_user_ids)
print("{} unique unsers extracted".format(len(unique_user_ids)))
# Out:
# 124439 unique unsers extracted

# %%
uid_df=pd.DataFrame({"uid":pd.Series(total_user_ids),"uid_count":pd.Series(total_user_ids)})
uid_df.set_index("uid_count")
uid_count=uid_df.groupby("uid").agg("count").sort_values(by="uid_count",ascending=False)


uid_count.to_csv(os.path.join(folder,"uid_count.csv"),encoding="utf-8")
sum(uid_count["uid_count"]>100)
# Out:
# 8999

# %%
unique_user_ids=pd.read_csv(os.path.join(folder,"uid_count.csv"),encoding="utf-8")["uid"].tolist()
print("{} unique unsers extracted".format(len(unique_user_ids)))

try:
    user_df=pd.read_csv(os.path.join(folder,"uid_info.csv"),encoding="utf-8")
    user_id_2=user_df["user_id"].tolist()
    user_names=user_df["user_name"].tolist()
    join_dates=user_df["join_date"].tolist()
    beer_karmas=user_df["beer_karma"].tolist()
    beer_markeds=user_df["beer_marked"].tolist()
    sexs=user_df["sex"].tolist()
    locations=user_df["location"].tolist()

except FileNotFoundError:
    user_id_2=[]
    user_names=[]
    join_dates=[]
    beer_karmas=[]
    beer_markeds=[]
    sexs=[]
    locations=[]
    
err_counter=0

for i in range(len(unique_user_ids)):
    user_id=str(int(unique_user_ids[i]))
    if int(user_id) in user_id_2:
        pass
    
    else:
        user_url="https://www.beeradvocate.com/community/members/"+user_id
        r = requests.get(user_url)
        soup = BeautifulSoup(r.content,"lxml")

        try:
            print("start saving {}".format(i))
            user_link=soup.find_all(attrs={"property":"og:url"})[0].get("content")
            user_name=user_link.split("/")[-2].split(".")[0]

            stat=soup.find_all(class_="section infoBlock")[0].find_all("dd")
            join_date=stat[-6].string.strip()
            beer_karma=stat[-5].string
            beer_marked=stat[-4].string

            user_names.append(user_name)
            join_dates.append(join_date)
            beer_karmas.append(beer_karma)
            beer_markeds.append(beer_marked)


            info=soup.find_all(id="info")[0].find_all(class_="pairsColumns aboutPairs")[0].find_all("dd")
            sex=info[0].string
            location=info[-1].string
            sexs.append(sex)
            locations.append(location)
            user_id_2.append(user_id)

        except IndexError:
            err_counter+=1

        if i%100==0:
            user_df=pd.DataFrame({"user_id":pd.Series(user_id_2),"user_name":pd.Series(user_names),"join_date":pd.Series(join_dates),
                                  "beer_karma":pd.Series(beer_karmas),"beer_marked":pd.Series(beer_markeds),"sex":pd.Series(sexs),
                                  "location":pd.Series(locations)})
            user_df.to_csv(os.path.join(folder,"uid_info.csv"),encoding="utf-8")
            print("{} users saved".format(i))
            print("{} errors".format(err_counter))
    
print("all user information saved")
# Out:
# 124439 unique unsers extracted
# start saving 12
# start saving 14
# start saving 18
# start saving 20
# start saving 21
# start saving 22
# start saving 33
# start saving 35
# start saving 51
# start saving 52
# start saving 54
# start saving 56
# start saving 61
# start saving 65
# start saving 71
# start saving 83
# start saving 87
# start saving 88
# start saving 94
# start saving 96
# start saving 105
# start saving 106
# start saving 117
# start saving 120
# start saving 125
# start saving 130
# start saving 138
# start saving 148
# start saving 151
# start saving 163
# start saving 166
# start saving 168
# start saving 172
# start saving 174
# start saving 191
# start saving 205
# start saving 212
# start saving 218
# start saving 219
# start saving 228
# start saving 243
# start saving 246
# start saving 247
# start saving 260
# start saving 262
# start saving 265
# start saving 272
# start saving 279
# start saving 290
# start saving 291
# start saving 295
# start saving 297
# start saving 300
# 300 users saved
# 53 errors
# start saving 305
# start saving 324
# start saving 329
# start saving 333
# start saving 342
# start saving 344
# start saving 351
# start saving 363
# start saving 366
# start saving 372
# start saving 373
# start saving 377
# start saving 381
# start saving 399
# start saving 407
# start saving 425
# start saving 433
# start saving 435
# start saving 437
# start saving 438
# start saving 443
# start saving 451
# start saving 467
# start saving 471
# start saving 485
# start saving 491
# start saving 495
# start saving 500
# 500 users saved
# 81 errors
# start saving 504
# start saving 506
# start saving 518
# start saving 526
# start saving 540
# start saving 544
# start saving 548
# start saving 564
# start saving 565
# start saving 568
# start saving 573
# start saving 575
# start saving 576
# start saving 578
# start saving 581
# start saving 583
# start saving 584
# start saving 586
# start saving 593
# start saving 601
# start saving 602
# start saving 603
# start saving 604
# start saving 605
# start saving 606
# start saving 607
# start saving 608
# start saving 609
# start saving 610
# start saving 611
# start saving 612
# start saving 613
# start saving 614
# start saving 615
# start saving 616
# start saving 617
# start saving 618
# start saving 619
# start saving 620
# start saving 621
# start saving 622
# start saving 623
# start saving 624
# start saving 625
# start saving 626
# start saving 627
# start saving 628
# start saving 629
# start saving 630
# start saving 631
# start saving 632
# start saving 633
# start saving 634
# start saving 635
# start saving 636
# start saving 637
# start saving 638
# start saving 639
# start saving 640
# start saving 641
# start saving 642
# start saving 643
# start saving 644
# start saving 645
# start saving 646
# start saving 647
# start saving 648
# start saving 649
# start saving 650
# start saving 651
# start saving 652
# start saving 653
# start saving 654
# start saving 655
# start saving 656
# start saving 657
# start saving 658
# start saving 659
# start saving 660
# start saving 661
# start saving 662
# start saving 663
# start saving 664
# start saving 665
# start saving 666
# start saving 667
# start saving 668
# start saving 669
# start saving 670
# start saving 671
# start saving 672
# start saving 673
# start saving 674
# start saving 675
# start saving 676
# start saving 677
# start saving 678
# start saving 679
# start saving 680
# start saving 681
# start saving 682
# start saving 683
# start saving 684
# start saving 685
# start saving 686
# start saving 687
# start saving 688
# start saving 689
# start saving 690
# start saving 691
# start saving 692
# start saving 693
# start saving 694
# start saving 695
# start saving 696
# start saving 697
# start saving 698
# start saving 699
# start saving 700
# 700 users saved
# 115 errors
# start saving 701
# start saving 702
# start saving 703
# start saving 704
# start saving 705
# start saving 706
# start saving 707
# start saving 708
# start saving 709
# start saving 710
# start saving 711
# start saving 712
# start saving 713
# start saving 714
# start saving 715
# start saving 716
# start saving 717
# start saving 718
# start saving 719
# start saving 720
# start saving 721
# start saving 722
# start saving 723
# start saving 724
# start saving 725
# start saving 726
# start saving 727
# start saving 728
# start saving 729
# start saving 730
# start saving 731
# start saving 732
# start saving 733
# start saving 734
# start saving 735
# start saving 736
# start saving 737
# start saving 738
# start saving 739
# start saving 740
# start saving 741
# start saving 742
# start saving 743
# start saving 744
# start saving 745
# start saving 746
# start saving 747
# start saving 748
# start saving 749
# start saving 750
# start saving 751
# start saving 752
# start saving 753
# start saving 754
# start saving 755
# start saving 756
# start saving 757
# start saving 758
# start saving 759
# start saving 760
# start saving 761
# start saving 762
# start saving 763
# start saving 764
# start saving 765
# start saving 766
# start saving 767
# start saving 768
# start saving 769
# start saving 770
# start saving 771
# start saving 772
# start saving 773
# start saving 774
# start saving 775
# start saving 776
# start saving 777
# start saving 778
# start saving 779
# start saving 780
# start saving 781
# start saving 782
# start saving 783
# start saving 784
# start saving 785
# start saving 786
# start saving 787
# start saving 788
# start saving 789
# start saving 790
# start saving 791
# start saving 792
# start saving 793
# start saving 794
# start saving 795
# start saving 796
# start saving 797
# start saving 798
# start saving 799
# start saving 800
# 800 users saved
# 132 errors
# start saving 801
# start saving 802
# start saving 803
# start saving 804
# start saving 805
# start saving 806
# start saving 807
# start saving 808
# start saving 809
# start saving 810
# start saving 811
# start saving 812
# start saving 813
# start saving 814
# start saving 815
# start saving 816
# start saving 817
# start saving 818
# start saving 819
# start saving 820
# start saving 821
# start saving 822
# start saving 823
# start saving 824
# start saving 825
# start saving 826
# start saving 827
# start saving 828
# start saving 829
# start saving 830
# start saving 831
# start saving 832
# start saving 833
# start saving 834
# start saving 835
# start saving 836
# start saving 837
# start saving 838
# start saving 839
# start saving 840
# start saving 841
# start saving 842
# start saving 843
# start saving 844
# start saving 845
# start saving 846
# start saving 847
# start saving 848
# start saving 849
# start saving 850
# start saving 851
# start saving 852
# start saving 853
# start saving 854
# start saving 855
# start saving 856
# start saving 857
# start saving 858
# start saving 859
# start saving 860
# start saving 861
# start saving 862
# start saving 863
# start saving 864
# start saving 865
# start saving 866
# start saving 867
# start saving 868
# start saving 869
# start saving 870
# start saving 871
# start saving 872
# start saving 873
# start saving 874
# start saving 875
# start saving 876
# start saving 877
# start saving 878
# start saving 879
# start saving 880
# start saving 881
# start saving 882
# start saving 883
# start saving 884
# start saving 885
# start saving 886
# start saving 887
# start saving 888
# start saving 889
# start saving 890
# start saving 891
# start saving 892
# start saving 893
# start saving 894
# start saving 895
# start saving 896
# start saving 897
# start saving 898
# start saving 899
# start saving 900
# 900 users saved
# 145 errors
# start saving 901
# start saving 902
# start saving 903
# start saving 904
# start saving 905
# start saving 906
# start saving 907
# start saving 908
# start saving 909
# start saving 910
# start saving 911
# start saving 912
# start saving 913
# start saving 914
# start saving 915
# start saving 916
# start saving 917
# start saving 918
# start saving 919
# start saving 920
# start saving 921
# start saving 922
# start saving 923
# start saving 924
# start saving 925
# start saving 926
# start saving 927
# start saving 928
# start saving 929
# start saving 930
# start saving 931
# start saving 932
# start saving 933
# start saving 934
# start saving 935
# start saving 936
# start saving 937
# start saving 938
# start saving 939
# start saving 940
# start saving 941
# start saving 942
# start saving 943
# start saving 944
# start saving 945
# start saving 946
# start saving 947
# start saving 948
# start saving 949
# start saving 950
# start saving 951
# start saving 952
# start saving 953
# start saving 954
# start saving 955
# start saving 956
# start saving 957
# start saving 958
# start saving 959
# start saving 960
# start saving 961
# start saving 962
# start saving 963
# start saving 964
# start saving 965
# start saving 966
# start saving 967
# start saving 968
# start saving 969
# start saving 970
# start saving 971
# start saving 972
# start saving 973
# start saving 974
# start saving 975
# start saving 976
# start saving 977
# start saving 978
# start saving 979
# start saving 980
# start saving 981
# start saving 982
# start saving 983
# start saving 984
# start saving 985
# start saving 986
# start saving 987
# start saving 988
# start saving 989
# start saving 990
# start saving 991
# start saving 992
# start saving 993
# start saving 994
# start saving 995
# start saving 996
# start saving 997
# start saving 998
# start saving 999
# start saving 1000
# 1000 users saved
# 158 errors
# start saving 1001
# start saving 1002
# start saving 1003
# start saving 1004
# start saving 1005
# start saving 1006
# start saving 1007
# start saving 1008
# start saving 1009
# start saving 1010
# start saving 1011
# start saving 1012
# start saving 1013
# start saving 1014
# start saving 1015
# start saving 1016
# start saving 1017
# start saving 1018
# start saving 1019
# start saving 1020
# start saving 1021
# start saving 1022
# start saving 1023
# start saving 1024
# start saving 1025
# start saving 1026
# start saving 1027
# start saving 1028
# start saving 1029
# start saving 1030
# start saving 1031
# start saving 1032
# start saving 1033
# start saving 1034
# start saving 1035
# start saving 1036
# start saving 1037
# start saving 1038
# start saving 1039
# start saving 1040
# start saving 1041
# start saving 1042
# start saving 1043
# start saving 1044
# start saving 1045
# start saving 1046
# start saving 1047
# start saving 1048
# start saving 1049
# start saving 1050
# start saving 1051
# start saving 1052
# start saving 1053
# start saving 1054
# start saving 1055
# start saving 1056
# start saving 1057
# start saving 1058
# start saving 1059
# start saving 1060
# start saving 1061
# start saving 1062
# start saving 1063
# start saving 1064
# start saving 1065
# start saving 1066
# start saving 1067
# start saving 1068
# start saving 1069
# start saving 1070
# start saving 1071
# start saving 1072
# start saving 1073
# start saving 1074
# start saving 1075
# start saving 1076
# start saving 1077
# start saving 1078
# start saving 1079
# start saving 1080
# start saving 1081
# start saving 1082
# start saving 1083
# start saving 1084
# start saving 1085
# start saving 1086
# start saving 1087
# start saving 1088
# start saving 1089
# start saving 1090
# start saving 1091
# start saving 1092
# start saving 1093
# start saving 1094
# start saving 1095
# start saving 1096
# start saving 1097
# start saving 1098
# start saving 1099
# start saving 1100
# 1100 users saved
# 174 errors
# start saving 1101
# start saving 1102
# start saving 1103
# start saving 1104
# start saving 1105
# start saving 1106
# start saving 1107
# start saving 1108
# start saving 1109
# start saving 1110
# start saving 1111
# start saving 1112
# start saving 1113
# start saving 1114
# start saving 1115
# start saving 1116
# start saving 1117
# start saving 1118
# start saving 1119
# start saving 1120
# start saving 1121
# start saving 1122
# start saving 1123
# start saving 1124
# start saving 1125
# start saving 1126
# start saving 1127
# start saving 1128
# start saving 1129
# start saving 1130
# start saving 1131
# start saving 1132
# start saving 1133
# start saving 1134
# start saving 1135
# start saving 1136
# start saving 1137
# start saving 1138
# start saving 1139
# start saving 1140
# start saving 1141
# start saving 1142
# start saving 1143
# start saving 1144
# start saving 1145
# start saving 1146
# start saving 1147
# start saving 1148
# start saving 1149
# start saving 1150
# start saving 1151
# start saving 1152
# start saving 1153
# start saving 1154
# start saving 1155
# start saving 1156
# start saving 1157
# start saving 1158
# start saving 1159
# start saving 1160
# start saving 1161
# start saving 1162
# start saving 1163
# start saving 1164
# start saving 1165
# start saving 1166
# start saving 1167
# start saving 1168
# start saving 1169
# start saving 1170
# start saving 1171
# start saving 1172
# start saving 1173
# start saving 1174
# start saving 1175
# start saving 1176
# start saving 1177
# start saving 1178
# start saving 1179
# start saving 1180
# start saving 1181
# start saving 1182
# start saving 1183
# start saving 1184
# start saving 1185
# start saving 1186
# start saving 1187
# start saving 1188
# start saving 1189
# start saving 1190
# start saving 1191
# start saving 1192
# start saving 1193
# start saving 1194
# start saving 1195
# start saving 1196
# start saving 1197
# start saving 1198
# start saving 1199
# start saving 1200
# 1200 users saved
# 190 errors
# start saving 1201
# start saving 1202
# start saving 1203
# start saving 1204
# start saving 1205
# start saving 1206
# start saving 1207
# start saving 1208
# start saving 1209
# start saving 1210
# start saving 1211
# start saving 1212
# start saving 1213
# start saving 1214
# start saving 1215
# start saving 1216
# start saving 1217
# start saving 1218
# start saving 1219
# start saving 1220
# start saving 1221
# start saving 1222
# start saving 1223
# start saving 1224
# start saving 1225
# start saving 1226
# start saving 1227
# start saving 1228
# start saving 1229
# start saving 1230
# start saving 1231
# start saving 1232
# start saving 1233
# start saving 1234
# start saving 1235
# start saving 1236
# start saving 1237
# start saving 1238
# start saving 1239
# start saving 1240
# start saving 1241
# start saving 1242
# start saving 1243
# start saving 1244
# start saving 1245
# start saving 1246
# start saving 1247
# start saving 1248
# start saving 1249
# start saving 1250
# start saving 1251
# start saving 1252
# start saving 1253
# start saving 1254
# start saving 1255
# start saving 1256
# start saving 1257
# start saving 1258
# start saving 1259
# start saving 1260
# start saving 1261
# start saving 1262
# start saving 1263
# start saving 1264
# start saving 1265
# start saving 1266
# start saving 1267
# start saving 1268
# start saving 1269
# start saving 1270
# start saving 1271
# start saving 1272
# start saving 1273
# start saving 1274
# start saving 1275
# start saving 1276
# start saving 1277
# start saving 1278
# start saving 1279
# start saving 1280
# start saving 1281
# start saving 1282
# start saving 1283
# start saving 1284
# start saving 1285
# start saving 1286
# start saving 1287
# start saving 1288
# start saving 1289
# start saving 1290
# start saving 1291
# start saving 1292
# start saving 1293
# start saving 1294
# start saving 1295
# start saving 1296
# start saving 1297
# start saving 1298
# start saving 1299
# start saving 1300
# 1300 users saved
# 203 errors
# start saving 1301
# start saving 1302
# start saving 1303
# start saving 1304
# start saving 1305
# start saving 1306
# start saving 1307
# start saving 1308
# start saving 1309
# start saving 1310
# start saving 1311
# start saving 1312
# start saving 1313
# start saving 1314
# start saving 1315
# start saving 1316
# start saving 1317
# start saving 1318
# start saving 1319
# start saving 1320
# start saving 1321
# start saving 1322
# start saving 1323
# start saving 1324
# start saving 1325
# start saving 1326
# start saving 1327
# start saving 1328
# start saving 1329
# start saving 1330
# start saving 1331
# start saving 1332
# start saving 1333
# start saving 1334
# start saving 1335
# start saving 1336
# start saving 1337
# start saving 1338
# start saving 1339
# start saving 1340
# start saving 1341
# start saving 1342
# start saving 1343
# start saving 1344
# start saving 1345
# start saving 1346
# start saving 1347
# start saving 1348
# start saving 1349
# start saving 1350
# start saving 1351
# start saving 1352
# start saving 1353
# start saving 1354
# start saving 1355
# start saving 1356
# start saving 1357
# start saving 1358
# start saving 1359
# start saving 1360
# start saving 1361
# start saving 1362
# start saving 1363
# start saving 1364
# start saving 1365
# start saving 1366
# start saving 1367
# start saving 1368
# start saving 1369
# start saving 1370
# start saving 1371
# start saving 1372
# start saving 1373
# start saving 1374
# start saving 1375
# start saving 1376
# start saving 1377
# start saving 1378
# start saving 1379
# start saving 1380
# start saving 1381
# start saving 1382
# start saving 1383
# start saving 1384
# start saving 1385
# start saving 1386
# start saving 1387
# start saving 1388
# start saving 1389
# start saving 1390
# start saving 1391
# start saving 1392
# start saving 1393
# start saving 1394
# start saving 1395
# start saving 1396
# start saving 1397
# start saving 1398
# start saving 1399
# start saving 1400
# 1400 users saved
# 214 errors
# start saving 1401
# start saving 1402
# start saving 1403
# start saving 1404
# start saving 1405
# start saving 1406
# start saving 1407
# start saving 1408
# start saving 1409
# start saving 1410
# start saving 1411
# start saving 1412
# start saving 1413
# start saving 1414
# start saving 1415
# start saving 1416
# start saving 1417
# start saving 1418
# start saving 1419
# start saving 1420
# start saving 1421
# start saving 1422
# start saving 1423
# start saving 1424
# start saving 1425
# start saving 1426
# start saving 1427
# start saving 1428
# start saving 1429
# start saving 1430
# start saving 1431
# start saving 1432
# start saving 1433
# start saving 1434
# start saving 1435
# start saving 1436
# start saving 1437
# start saving 1438
# start saving 1439
# start saving 1440
# start saving 1441
# start saving 1442
# start saving 1443
# start saving 1444
# start saving 1445
# start saving 1446
# start saving 1447
# start saving 1448
# start saving 1449
# start saving 1450
# start saving 1451
# start saving 1452
# start saving 1453
# start saving 1454
# start saving 1455
# start saving 1456
# start saving 1457
# start saving 1458
# start saving 1459
# start saving 1460
# start saving 1461
# start saving 1462
# start saving 1463
# start saving 1464
# start saving 1465
# start saving 1466
# start saving 1467
# start saving 1468
# start saving 1469
# start saving 1470
# start saving 1471
# start saving 1472
# start saving 1473
# start saving 1474
# start saving 1475
# start saving 1476
# start saving 1477
# start saving 1478
# start saving 1479
# start saving 1480
# start saving 1481
# start saving 1482
# start saving 1483
# start saving 1484
# start saving 1485
# start saving 1486
# start saving 1487
# start saving 1488
# start saving 1489
# start saving 1490
# start saving 1491
# start saving 1492
# start saving 1493
# start saving 1494
# start saving 1495
# start saving 1496
# start saving 1497
# start saving 1498
# start saving 1499
# start saving 1500
# 1500 users saved
# 226 errors
# start saving 1501
# start saving 1502
# start saving 1503
# start saving 1504
# start saving 1505
# start saving 1506
# start saving 1507
# start saving 1508
# start saving 1509
# start saving 1510
# start saving 1511
# start saving 1512
# start saving 1513
# start saving 1514
# start saving 1515
# start saving 1516
# start saving 1517
# start saving 1518
# start saving 1519
# start saving 1520
# start saving 1521
# start saving 1522
# start saving 1523
# start saving 1524
# start saving 1525
# start saving 1526
# start saving 1527
# start saving 1528
# start saving 1529
# start saving 1530
# start saving 1531
# start saving 1532
# start saving 1533
# start saving 1534
# start saving 1535
# start saving 1536
# start saving 1537
# start saving 1538
# start saving 1539
# start saving 1540
# start saving 1541
# start saving 1542
# start saving 1543
# start saving 1544
# start saving 1545
# start saving 1546
# start saving 1547
# start saving 1548
# start saving 1549
# start saving 1550
# start saving 1551
# start saving 1552
# start saving 1553
# start saving 1554
# start saving 1555
# start saving 1556
# start saving 1557
# start saving 1558
# start saving 1559
# start saving 1560
# start saving 1561
# start saving 1562
# start saving 1563
# start saving 1564
# start saving 1565
# start saving 1566
# start saving 1567
# start saving 1568
# start saving 1569
# start saving 1570
# start saving 1571
# start saving 1572
# start saving 1573
# start saving 1574
# start saving 1575
# start saving 1576
# start saving 1577
# start saving 1578
# start saving 1579
# start saving 1580
# start saving 1581
# start saving 1582
# start saving 1583
# start saving 1584
# start saving 1585
# start saving 1586
# start saving 1587
# start saving 1588
# start saving 1589
# start saving 1590
# start saving 1591
# start saving 1592
# start saving 1593
# start saving 1594
# start saving 1595
# start saving 1596
# start saving 1597
# start saving 1598
# start saving 1599
# start saving 1600
# 1600 users saved
# 237 errors
# start saving 1601
# start saving 1602
# start saving 1603
# start saving 1604
# start saving 1605
# start saving 1606
# start saving 1607
# start saving 1608
# start saving 1609
# start saving 1610
# start saving 1611
# start saving 1612
# start saving 1613
# start saving 1614
# start saving 1615
# start saving 1616
# start saving 1617
# start saving 1618
# start saving 1619
# start saving 1620
# start saving 1621
# start saving 1622
# start saving 1623
# start saving 1624
# start saving 1625
# start saving 1626
# start saving 1627
# start saving 1628
# start saving 1629
# start saving 1630
# start saving 1631
# start saving 1632
# start saving 1633
# start saving 1634
# start saving 1635
# start saving 1636
# start saving 1637
# start saving 1638
# start saving 1639
# start saving 1640
# start saving 1641
# start saving 1642
# start saving 1643
# start saving 1644
# start saving 1645
# start saving 1646
# start saving 1647
# start saving 1648
# start saving 1649
# start saving 1650
# start saving 1651
# start saving 1652
# start saving 1653
# start saving 1654
# start saving 1655
# start saving 1656
# start saving 1657
# start saving 1658
# start saving 1659
# start saving 1660
# start saving 1661
# start saving 1662
# start saving 1663
# start saving 1664
# start saving 1665
# start saving 1666
# start saving 1667
# start saving 1668
# start saving 1669
# start saving 1670
# start saving 1671
# start saving 1672
# start saving 1673
# start saving 1674
# start saving 1675
# start saving 1676
# start saving 1677
# start saving 1678
# start saving 1679
# start saving 1680
# start saving 1681
# start saving 1682
# start saving 1683
# start saving 1684
# start saving 1685
# start saving 1686
# start saving 1687
# start saving 1688
# start saving 1689
# start saving 1690
# start saving 1691
# start saving 1692
# start saving 1693
# start saving 1694
# start saving 1695
# start saving 1696
# start saving 1697
# start saving 1698
# start saving 1699
# start saving 1700
# 1700 users saved
# 246 errors
# start saving 1701
# start saving 1702
# start saving 1703
# start saving 1704
# start saving 1705
# start saving 1706
# start saving 1707
# start saving 1708
# start saving 1709
# start saving 1710
# start saving 1711
# start saving 1712
# start saving 1713
# start saving 1714
# start saving 1715
# start saving 1716
# start saving 1717
# start saving 1718
# start saving 1719
# start saving 1720
# start saving 1721
# start saving 1722
# start saving 1723
# start saving 1724
# start saving 1725
# start saving 1726
# start saving 1727
# start saving 1728
# start saving 1729
# start saving 1730
# start saving 1731
# start saving 1732
# start saving 1733
# start saving 1734
# start saving 1735
# start saving 1736
# start saving 1737
# start saving 1738
# start saving 1739
# start saving 1740
# start saving 1741
# start saving 1742
# start saving 1743
# start saving 1744
# start saving 1745
# start saving 1746
# start saving 1747
# start saving 1748
# start saving 1749
# start saving 1750
# start saving 1751
# start saving 1752
# start saving 1753
# start saving 1754
# start saving 1755
# start saving 1756
# start saving 1757
# start saving 1758
# start saving 1759
# start saving 1760
# start saving 1761
# start saving 1762
# start saving 1763
# start saving 1764
# start saving 1765
# start saving 1766
# start saving 1767
# start saving 1768
# start saving 1769
# start saving 1770
# start saving 1771
# start saving 1772
# start saving 1773
# start saving 1774
# start saving 1775
# start saving 1776
# start saving 1777
# start saving 1778
# start saving 1779
# start saving 1780
# start saving 1781
# start saving 1782
# start saving 1783
# start saving 1784
# start saving 1785
# start saving 1786
# start saving 1787
# start saving 1788
# start saving 1789
# start saving 1790
# start saving 1791
# start saving 1792
# start saving 1793
# start saving 1794
# start saving 1795
# start saving 1796
# start saving 1797
# start saving 1798
# start saving 1799
# start saving 1800
# 1800 users saved
# 254 errors
# start saving 1801
# start saving 1802
# start saving 1803
# start saving 1804
# start saving 1805
# start saving 1806
# start saving 1807
# start saving 1808
# start saving 1809
# start saving 1810
# start saving 1811
# start saving 1812
# start saving 1813
# start saving 1814
# start saving 1815
# start saving 1816
# start saving 1817
# start saving 1818
# start saving 1819
# start saving 1820
# start saving 1821
# start saving 1822
# start saving 1823
# start saving 1824
# start saving 1825
# start saving 1826
# start saving 1827
# start saving 1828
# start saving 1829
# start saving 1830
# start saving 1831
# start saving 1832
# start saving 1833
# start saving 1834
# start saving 1835
# start saving 1836
# start saving 1837
# start saving 1838
# start saving 1839
# start saving 1840
# start saving 1841
# start saving 1842
# start saving 1843
# start saving 1844
# start saving 1845
# start saving 1846
# start saving 1847
# start saving 1848
# start saving 1849
# start saving 1850
# start saving 1851
# start saving 1852
# start saving 1853
# start saving 1854
# start saving 1855
# start saving 1856
# start saving 1857
# start saving 1858
# start saving 1859
# start saving 1860
# start saving 1861
# start saving 1862
# start saving 1863
# start saving 1864
# start saving 1865
# start saving 1866
# start saving 1867
# start saving 1868
# start saving 1869
# start saving 1870
# start saving 1871
# start saving 1872
# start saving 1873
# start saving 1874
# start saving 1875
# start saving 1876
# start saving 1877
# start saving 1878
# start saving 1879
# start saving 1880
# start saving 1881
# start saving 1882
# start saving 1883
# start saving 1884
# start saving 1885
# start saving 1886
# start saving 1887
# start saving 1888
# start saving 1889
# start saving 1890
# start saving 1891
# start saving 1892
# start saving 1893
# start saving 1894
# start saving 1895
# start saving 1896
# start saving 1897
# start saving 1898
# start saving 1899
# start saving 1900
# 1900 users saved
# 267 errors
# start saving 1901
# start saving 1902
# start saving 1903
# start saving 1904
# start saving 1905
# start saving 1906
# start saving 1907
# start saving 1908
# start saving 1909
# start saving 1910
# start saving 1911
# start saving 1912
# start saving 1913
# start saving 1914
# start saving 1915
# start saving 1916
# start saving 1917
# start saving 1918
# start saving 1919
# start saving 1920
# start saving 1921
# start saving 1922
# start saving 1923
# start saving 1924
# start saving 1925
# start saving 1926
# start saving 1927
# start saving 1928
# start saving 1929
# start saving 1930
# start saving 1931
# start saving 1932
# start saving 1933
# start saving 1934
# start saving 1935
# start saving 1936
# start saving 1937
# start saving 1938
# start saving 1939
# start saving 1940
# start saving 1941
# start saving 1942
# start saving 1943
# start saving 1944
# start saving 1945
# start saving 1946
# start saving 1947
# start saving 1948
# start saving 1949
# start saving 1950
# start saving 1951
# start saving 1952
# start saving 1953
# start saving 1954
# start saving 1955
# start saving 1956
# start saving 1957
# start saving 1958
# start saving 1959
# start saving 1960
# start saving 1961
# start saving 1962
# start saving 1963
# start saving 1964
# start saving 1965
# start saving 1966
# start saving 1967
# start saving 1968
# start saving 1969
# start saving 1970
# start saving 1971
# start saving 1972
# start saving 1973
# start saving 1974
# start saving 1975
# start saving 1976
# start saving 1977
# start saving 1978
# start saving 1979
# start saving 1980
# start saving 1981
# start saving 1982
# start saving 1983
# start saving 1984
# start saving 1985
# start saving 1986
# start saving 1987
# start saving 1988
# start saving 1989
# start saving 1990
# start saving 1991
# start saving 1992
# start saving 1993
# start saving 1994
# start saving 1995
# start saving 1996
# start saving 1997
# start saving 1998
# start saving 1999
# start saving 2000
# 2000 users saved
# 273 errors
# start saving 2001
# start saving 2002
# start saving 2003
# start saving 2004
# start saving 2005
# start saving 2006
# start saving 2007
# start saving 2008
# start saving 2009
# start saving 2010
# start saving 2011
# start saving 2012
# start saving 2013
# start saving 2014
# start saving 2015
# start saving 2016
# start saving 2017
# start saving 2018
# start saving 2019
# start saving 2020
# start saving 2021
# start saving 2022
# start saving 2023
# start saving 2024
# start saving 2025
# start saving 2026
# start saving 2027
# start saving 2028
# start saving 2029
# start saving 2030
# start saving 2031
# start saving 2032
# start saving 2033
# start saving 2034
# start saving 2035
# start saving 2036
# start saving 2037
# start saving 2038
# start saving 2039
# start saving 2040
# start saving 2041
# start saving 2042
# start saving 2043
# start saving 2044
# start saving 2045
# start saving 2046
# start saving 2047
# start saving 2048
# start saving 2049
# start saving 2050
# start saving 2051
# start saving 2052
# start saving 2053
# start saving 2054
# start saving 2055
# start saving 2056
# start saving 2057
# start saving 2058
# start saving 2059
# start saving 2060
# start saving 2061
# start saving 2062
# start saving 2063
# start saving 2064
# start saving 2065
# start saving 2066
# start saving 2067
# start saving 2068
# start saving 2069
# start saving 2070
# start saving 2071
# start saving 2072
# start saving 2073
# start saving 2074
# start saving 2075
# start saving 2076
# start saving 2077
# start saving 2078
# start saving 2079
# start saving 2080
# start saving 2081
# start saving 2082
# start saving 2083
# start saving 2084
# start saving 2085
# start saving 2086
# start saving 2087
# start saving 2088
# start saving 2089
# start saving 2090
# start saving 2091
# start saving 2092
# start saving 2093
# start saving 2094
# start saving 2095
# start saving 2096
# start saving 2097
# start saving 2098
# start saving 2099
# start saving 2100
# 2100 users saved
# 287 errors
# start saving 2101
# start saving 2102
# start saving 2103
# start saving 2104
# start saving 2105
# start saving 2106
# start saving 2107
# start saving 2108
# start saving 2109
# start saving 2110
# start saving 2111
# start saving 2112
# start saving 2113
# start saving 2114
# start saving 2115
# start saving 2116
# start saving 2117
# start saving 2118
# start saving 2119
# start saving 2120
# start saving 2121
# start saving 2122
# start saving 2123
# start saving 2124
# start saving 2125
# start saving 2126
# start saving 2127
# start saving 2128
# start saving 2129
# start saving 2130
# start saving 2131
# start saving 2132
# start saving 2133
# start saving 2134
# start saving 2135
# start saving 2136
# start saving 2137
# start saving 2138
# start saving 2139
# start saving 2140
# start saving 2141
# start saving 2142
# start saving 2143
# start saving 2144
# start saving 2145
# start saving 2146
# start saving 2147
# start saving 2148
# start saving 2149
# start saving 2150
# start saving 2151
# start saving 2152
# start saving 2153
# start saving 2154
# start saving 2155
# start saving 2156
# start saving 2157
# start saving 2158
# start saving 2159
# start saving 2160
# start saving 2161
# start saving 2162
# start saving 2163
# start saving 2164
# start saving 2165
# start saving 2166
# start saving 2167
# start saving 2168
# start saving 2169
# start saving 2170
# start saving 2171
# start saving 2172
# start saving 2173
# start saving 2174
# start saving 2175
# start saving 2176
# start saving 2177
# start saving 2178
# start saving 2179
# start saving 2180
# start saving 2181
# start saving 2182
# start saving 2183
# start saving 2184
# start saving 2185
# start saving 2186
# start saving 2187
# start saving 2188
# start saving 2189
# start saving 2190
# start saving 2191
# start saving 2192
# start saving 2193
# start saving 2194
# start saving 2195
# start saving 2196
# start saving 2197
# start saving 2198
# start saving 2199
# start saving 2200
# 2200 users saved
# 298 errors
# start saving 2201
# start saving 2202
# start saving 2203
# start saving 2204
# start saving 2205
# start saving 2206
# start saving 2207
# start saving 2208
# start saving 2209
# start saving 2210
# start saving 2211
# start saving 2212
# start saving 2213
# start saving 2214
# start saving 2215
# start saving 2216
# start saving 2217
# start saving 2218
# start saving 2219
# start saving 2220
# start saving 2221
# start saving 2222
# start saving 2223
# start saving 2224
# start saving 2225
# start saving 2226
# start saving 2227
# start saving 2228
# start saving 2229
# start saving 2230
# start saving 2231
# start saving 2232
# start saving 2233
# start saving 2234
# start saving 2235
# start saving 2236
# start saving 2237
# start saving 2238
# start saving 2239
# start saving 2240
# start saving 2241
# start saving 2242
# start saving 2243
# start saving 2244
# start saving 2245
# start saving 2246
# start saving 2247
# start saving 2248
# start saving 2249
# start saving 2250
# start saving 2251
# start saving 2252
# start saving 2253
# start saving 2254
# start saving 2255
# start saving 2256
# start saving 2257
# start saving 2258
# start saving 2259
# start saving 2260
# start saving 2261
# start saving 2262
# start saving 2263
# start saving 2264
# start saving 2265
# start saving 2266
# start saving 2267
# start saving 2268
# start saving 2269
# start saving 2270
# start saving 2271
# start saving 2272
# start saving 2273
# start saving 2274
# start saving 2275
# start saving 2276
# start saving 2277
# start saving 2278
# start saving 2279
# start saving 2280
# start saving 2281
# start saving 2282
# start saving 2283
# start saving 2284
# start saving 2285
# start saving 2286
# start saving 2287
# start saving 2288
# start saving 2289
# start saving 2290
# start saving 2291
# start saving 2292
# start saving 2293
# start saving 2294
# start saving 2295
# start saving 2296
# start saving 2297
# start saving 2298
# start saving 2299
# start saving 2300
# 2300 users saved
# 313 errors
# start saving 2301
# start saving 2302
# start saving 2303
# start saving 2304
# start saving 2305
# start saving 2306
# start saving 2307
# start saving 2308
# start saving 2309
# start saving 2310
# start saving 2311
# start saving 2312
# start saving 2313
# start saving 2314
# start saving 2315
# start saving 2316
# start saving 2317
# start saving 2318
# start saving 2319
# start saving 2320
# start saving 2321
# start saving 2322
# start saving 2323
# start saving 2324
# start saving 2325
# start saving 2326
# start saving 2327
# start saving 2328
# start saving 2329
# start saving 2330
# start saving 2331
# start saving 2332
# start saving 2333
# start saving 2334
# start saving 2335
# start saving 2336
# start saving 2337
# start saving 2338
# start saving 2339
# start saving 2340
# start saving 2341
# start saving 2342
# start saving 2343
# start saving 2344
# start saving 2345
# start saving 2346
# start saving 2347
# start saving 2348
# start saving 2349
# start saving 2350
# start saving 2351
# start saving 2352
# start saving 2353
# start saving 2354
# start saving 2355
# start saving 2356
# start saving 2357
# start saving 2358
# start saving 2359
# start saving 2360
# start saving 2361
# start saving 2362
# start saving 2363
# start saving 2364
# start saving 2365
# start saving 2366
# start saving 2367
# start saving 2368
# start saving 2369
# start saving 2370
# start saving 2371
# start saving 2372
# start saving 2373
# start saving 2374
# start saving 2375
# start saving 2376
# start saving 2377
# start saving 2378
# start saving 2379
# start saving 2380
# start saving 2381
# start saving 2382
# start saving 2383
# start saving 2384
# start saving 2385
# start saving 2386
# start saving 2387
# start saving 2388
# start saving 2389
# start saving 2390
# start saving 2391
# start saving 2392
# start saving 2393
# start saving 2394
# start saving 2395
# start saving 2396
# start saving 2397
# start saving 2398
# start saving 2399
# start saving 2400
# 2400 users saved
# 329 errors
# start saving 2401
# start saving 2402
# start saving 2403
# start saving 2404
# start saving 2405
# start saving 2406
# start saving 2407
# start saving 2408
# start saving 2409
# start saving 2410
# start saving 2411
# start saving 2412
# start saving 2413
# start saving 2414
# start saving 2415
# start saving 2416
# start saving 2417
# start saving 2418
# start saving 2419
# start saving 2420
# start saving 2421
# start saving 2422
# start saving 2423
# start saving 2424
# start saving 2425
# start saving 2426
# start saving 2427
# start saving 2428
# start saving 2429
# start saving 2430
# start saving 2431
# start saving 2432
# start saving 2433
# start saving 2434
# start saving 2435
# start saving 2436
# start saving 2437
# start saving 2438
# start saving 2439
# start saving 2440
# start saving 2441
# start saving 2442
# start saving 2443
# start saving 2444
# start saving 2445
# start saving 2446
# start saving 2447
# start saving 2448
# start saving 2449
# start saving 2450
# start saving 2451
# start saving 2452
# start saving 2453
# start saving 2454
# start saving 2455
# start saving 2456
# start saving 2457
# start saving 2458
# start saving 2459
# start saving 2460
# start saving 2461
# start saving 2462
# start saving 2463
# start saving 2464
# start saving 2465
# start saving 2466
# start saving 2467
# start saving 2468
# start saving 2469
# start saving 2470
# start saving 2471
# start saving 2472
# start saving 2473
# start saving 2474
# start saving 2475
# start saving 2476
# start saving 2477
# start saving 2478
# start saving 2479
# start saving 2480
# start saving 2481
# start saving 2482
# start saving 2483
# start saving 2484
# start saving 2485
# start saving 2486
# start saving 2487
# start saving 2488
# start saving 2489
# start saving 2490
# start saving 2491
# start saving 2492
# start saving 2493
# start saving 2494
# start saving 2495
# start saving 2496
# start saving 2497
# start saving 2498
# start saving 2499
# start saving 2500
# 2500 users saved
# 341 errors
# start saving 2501
# start saving 2502
# start saving 2503
# start saving 2504
# start saving 2505
# start saving 2506
# start saving 2507
# start saving 2508
# start saving 2509
# start saving 2510
# start saving 2511
# start saving 2512
# start saving 2513
# start saving 2514
# start saving 2515
# start saving 2516
# start saving 2517
# start saving 2518
# start saving 2519
# start saving 2520
# start saving 2521
# start saving 2522
# start saving 2523
# start saving 2524
# start saving 2525
# start saving 2526
# start saving 2527
# start saving 2528
# start saving 2529
# start saving 2530
# start saving 2531
# start saving 2532
# start saving 2533
# start saving 2534
# start saving 2535
# start saving 2536
# start saving 2537
# start saving 2538
# start saving 2539
# start saving 2540
# start saving 2541
# start saving 2542
# start saving 2543
# start saving 2544
# start saving 2545
# start saving 2546
# start saving 2547
# start saving 2548
# start saving 2549
# start saving 2550
# start saving 2551
# start saving 2552
# start saving 2553
# start saving 2554
# start saving 2555
# start saving 2556
# start saving 2557
# start saving 2558
# start saving 2559
# start saving 2560
# start saving 2561
# start saving 2562
# start saving 2563
# start saving 2564
# start saving 2565
# start saving 2566
# start saving 2567
# start saving 2568
# start saving 2569
# start saving 2570
# start saving 2571
# start saving 2572
# start saving 2573
# start saving 2574
# start saving 2575
# start saving 2576
# start saving 2577
# start saving 2578
# start saving 2579
# start saving 2580
# start saving 2581
# start saving 2582
# start saving 2583
# start saving 2584
# start saving 2585
# start saving 2586
# start saving 2587
# start saving 2588
# start saving 2589
# start saving 2590
# start saving 2591
# start saving 2592
# start saving 2593
# start saving 2594
# start saving 2595
# start saving 2596
# start saving 2597
# start saving 2598
# start saving 2599
# start saving 2600
# 2600 users saved
# 357 errors
# start saving 2601
# start saving 2602
# start saving 2603
# start saving 2604
# start saving 2605
# start saving 2606
# start saving 2607
# start saving 2608
# start saving 2609
# start saving 2610
# start saving 2611
# start saving 2612
# start saving 2613
# start saving 2614
# start saving 2615
# start saving 2616
# start saving 2617
# start saving 2618
# start saving 2619
# start saving 2620
# start saving 2621
# start saving 2622
# start saving 2623
# start saving 2624
# start saving 2625
# start saving 2626
# start saving 2627
# start saving 2628
# start saving 2629
# start saving 2630
# start saving 2631
# start saving 2632
# start saving 2633
# start saving 2634
# start saving 2635
# start saving 2636
# start saving 2637
# start saving 2638
# start saving 2639
# start saving 2640
# start saving 2641
# start saving 2642
# start saving 2643
# start saving 2644
# start saving 2645
# start saving 2646
# start saving 2647
# start saving 2648
# start saving 2649
# start saving 2650
# start saving 2651
# start saving 2652
# start saving 2653
# start saving 2654
# start saving 2655
# start saving 2656
# start saving 2657
# start saving 2658
# start saving 2659
# start saving 2660
# start saving 2661
# start saving 2662
# start saving 2663
# start saving 2664
# start saving 2665
# start saving 2666
# start saving 2667
# start saving 2668
# start saving 2669
# start saving 2670
# start saving 2671
# start saving 2672
# start saving 2673
# start saving 2674
# start saving 2675
# start saving 2676
# start saving 2677
# start saving 2678
# start saving 2679
# start saving 2680
# start saving 2681
# start saving 2682
# start saving 2683
# start saving 2684
# start saving 2685
# start saving 2686
# start saving 2687
# start saving 2688
# start saving 2689
# start saving 2690
# start saving 2691
# start saving 2692
# start saving 2693
# start saving 2694
# start saving 2695
# start saving 2696
# start saving 2697
# start saving 2698
# start saving 2699
# start saving 2700
# 2700 users saved
# 369 errors
# start saving 2701
# start saving 2702
# start saving 2703
# start saving 2704
# start saving 2705
# start saving 2706
# start saving 2707
# start saving 2708
# start saving 2709
# start saving 2710
# start saving 2711
# start saving 2712
# start saving 2713
# start saving 2714
# start saving 2715
# start saving 2716
# start saving 2717
# start saving 2718
# start saving 2719
# start saving 2720
# start saving 2721
# start saving 2722
# start saving 2723
# start saving 2724
# start saving 2725
# start saving 2726
# start saving 2727
# start saving 2728
# start saving 2729
# start saving 2730
# start saving 2731
# start saving 2732
# start saving 2733
# start saving 2734
# start saving 2735
# start saving 2736
# start saving 2737
# start saving 2738
# start saving 2739
# start saving 2740
# start saving 2741
# start saving 2742
# start saving 2743
# start saving 2744
# start saving 2745
# start saving 2746
# start saving 2747
# start saving 2748
# start saving 2749
# start saving 2750
# start saving 2751
# start saving 2752
# start saving 2753
# start saving 2754
# start saving 2755
# start saving 2756
# start saving 2757
# start saving 2758
# start saving 2759
# start saving 2760
# start saving 2761
# start saving 2762
# start saving 2763
# start saving 2764
# start saving 2765
# start saving 2766
# start saving 2767
# start saving 2768
# start saving 2769
# start saving 2770
# start saving 2771
# start saving 2772
# start saving 2773
# start saving 2774
# start saving 2775
# start saving 2776
# start saving 2777
# start saving 2778
# start saving 2779
# start saving 2780
# start saving 2781
# start saving 2782
# start saving 2783
# start saving 2784
# start saving 2785
# start saving 2786
# start saving 2787
# start saving 2788
# start saving 2789
# start saving 2790
# start saving 2791
# start saving 2792
# start saving 2793
# start saving 2794
# start saving 2795
# start saving 2796
# start saving 2797
# start saving 2798
# start saving 2799
# start saving 2800
# 2800 users saved
# 382 errors
# start saving 2801
# start saving 2802
# start saving 2803
# start saving 2804
# start saving 2805
# start saving 2806
# start saving 2807
# start saving 2808
# start saving 2809
# start saving 2810
# start saving 2811
# start saving 2812
# start saving 2813
# start saving 2814
# start saving 2815
# start saving 2816
# start saving 2817
# start saving 2818
# start saving 2819
# start saving 2820
# start saving 2821
# start saving 2822
# start saving 2823
# start saving 2824
# start saving 2825
# start saving 2826
# start saving 2827
# start saving 2828
# start saving 2829
# start saving 2830
# start saving 2831
# start saving 2832
# start saving 2833
# start saving 2834
# start saving 2835
# start saving 2836
# start saving 2837
# start saving 2838
# start saving 2839
# start saving 2840
# start saving 2841
# start saving 2842
# start saving 2843
# start saving 2844
# start saving 2845
# start saving 2846
# start saving 2847
# start saving 2848
# start saving 2849
# start saving 2850
# start saving 2851
# start saving 2852
# start saving 2853
# start saving 2854
# start saving 2855
# start saving 2856
# start saving 2857
# start saving 2858
# start saving 2859
# start saving 2860
# start saving 2861
# start saving 2862
# start saving 2863
# start saving 2864
# start saving 2865
# start saving 2866
# start saving 2867
# start saving 2868
# start saving 2869
# start saving 2870
# start saving 2871
# start saving 2872
# start saving 2873
# start saving 2874
# start saving 2875
# start saving 2876
# start saving 2877
# start saving 2878
# start saving 2879
# start saving 2880
# start saving 2881
# start saving 2882
# start saving 2883
# start saving 2884
# start saving 2885
# start saving 2886
# start saving 2887
# start saving 2888
# start saving 2889
# start saving 2890
# start saving 2891
# start saving 2892
# start saving 2893
# start saving 2894
# start saving 2895
# start saving 2896
# start saving 2897
# start saving 2898
# start saving 2899
# start saving 2900
# 2900 users saved
# 391 errors
# start saving 2901
# start saving 2902
# start saving 2903
# start saving 2904
# start saving 2905
# start saving 2906
# start saving 2907
# start saving 2908
# start saving 2909
# start saving 2910
# start saving 2911
# start saving 2912
# start saving 2913
# start saving 2914
# start saving 2915
# start saving 2916
# start saving 2917
# start saving 2918
# start saving 2919
# start saving 2920
# start saving 2921
# start saving 2922
# start saving 2923
# start saving 2924
# start saving 2925
# start saving 2926
# start saving 2927
# start saving 2928
# start saving 2929
# start saving 2930
# start saving 2931
# start saving 2932
# start saving 2933
# start saving 2934
# start saving 2935
# start saving 2936
# start saving 2937
# start saving 2938
# start saving 2939
# start saving 2940
# start saving 2941
# start saving 2942
# start saving 2943
# start saving 2944
# start saving 2945
# start saving 2946
# start saving 2947
# start saving 2948
# start saving 2949
# start saving 2950
# start saving 2951
# start saving 2952
# start saving 2953
# start saving 2954
# start saving 2955
# start saving 2956
# start saving 2957
# start saving 2958
# start saving 2959
# start saving 2960
# start saving 2961
# start saving 2962
# start saving 2963
# start saving 2964
# start saving 2965
# start saving 2966
# start saving 2967
# start saving 2968
# start saving 2969
# start saving 2970
# start saving 2971
# start saving 2972
# start saving 2973
# start saving 2974
# start saving 2975
# start saving 2976
# start saving 2977
# start saving 2978
# start saving 2979
# start saving 2980
# start saving 2981
# start saving 2982
# start saving 2983
# start saving 2984
# start saving 2985
# start saving 2986
# start saving 2987
# start saving 2988
# start saving 2989
# start saving 2990
# start saving 2991
# start saving 2992
# start saving 2993
# start saving 2994
# start saving 2995
# start saving 2996
# start saving 2997
# start saving 2998
# start saving 2999
# start saving 3000
# 3000 users saved
# 406 errors
# start saving 3001
# start saving 3002
# start saving 3003
# start saving 3004
# start saving 3005
# start saving 3006
# start saving 3007
# start saving 3008
# start saving 3009
# start saving 3010
# start saving 3011
# start saving 3012
# start saving 3013
# start saving 3014
# start saving 3015
# start saving 3016
# start saving 3017
# start saving 3018
# start saving 3019
# start saving 3020
# start saving 3021
# start saving 3022
# start saving 3023
# start saving 3024
# start saving 3025
# start saving 3026
# start saving 3027
# start saving 3028
# start saving 3029
# start saving 3030
# start saving 3031
# start saving 3032
# start saving 3033
# start saving 3034
# start saving 3035
# start saving 3036
# start saving 3037
# start saving 3038
# start saving 3039
# start saving 3040
# start saving 3041
# start saving 3042
# start saving 3043
# start saving 3044
# start saving 3045
# start saving 3046
# start saving 3047
# start saving 3048
# start saving 3049
# start saving 3050
# start saving 3051
# start saving 3052
# start saving 3053
# start saving 3054
# start saving 3055
# start saving 3056
# start saving 3057
# start saving 3058
# start saving 3059
# start saving 3060
# start saving 3061
# start saving 3062
# start saving 3063
# start saving 3064
# start saving 3065
# start saving 3066
# start saving 3067
# start saving 3068
# start saving 3069
# start saving 3070
# start saving 3071
# start saving 3072
# start saving 3073
# start saving 3074
# start saving 3075
# start saving 3076
# start saving 3077
# start saving 3078
# start saving 3079
# start saving 3080
# start saving 3081
# start saving 3082
# start saving 3083
# start saving 3084
# start saving 3085
# start saving 3086
# start saving 3087
# start saving 3088
# start saving 3089
# start saving 3090
# start saving 3091
# start saving 3092
# start saving 3093
# start saving 3094
# start saving 3095
# start saving 3096
# start saving 3097
# start saving 3098
# start saving 3099
# start saving 3100
# 3100 users saved
# 416 errors
# start saving 3101
# start saving 3102
# start saving 3103
# start saving 3104
# start saving 3105
# start saving 3106
# start saving 3107
# start saving 3108
# start saving 3109
# start saving 3110
# start saving 3111
# start saving 3112
# start saving 3113
# start saving 3114
# start saving 3115
# start saving 3116
# start saving 3117
# start saving 3118
# start saving 3119
# start saving 3120
# start saving 3121
# start saving 3122
# start saving 3123
# start saving 3124
# start saving 3125
# start saving 3126
# start saving 3127
# start saving 3128
# start saving 3129
# start saving 3130
# start saving 3131
# start saving 3132
# start saving 3133
# start saving 3134
# start saving 3135
# start saving 3136
# start saving 3137
# start saving 3138
# start saving 3139
# start saving 3140
# start saving 3141
# start saving 3142
# start saving 3143
# start saving 3144
# start saving 3145
# start saving 3146
# start saving 3147
# start saving 3148
# start saving 3149
# start saving 3150
# start saving 3151
# start saving 3152
# ...
# start saving 4486
# start saving 4487
# start saving 4488
# start saving 4489
# start saving 4490
# start saving 4491
# start saving 4492
# start saving 4493
# start saving 4494
# start saving 4495
# start saving 4496
# start saving 4497
# start saving 4498
# start saving 4499
# start saving 4500
# 4500 users saved
# 571 errors
# start saving 4501
# start saving 4502
# start saving 4503
# start saving 4504
# start saving 4505
# start saving 4506
# start saving 4507
# start saving 4508
# start saving 4509
# start saving 4510
# start saving 4511
# start saving 4512
# start saving 4513
# start saving 4514
# start saving 4515
# start saving 4516
# start saving 4517
# start saving 4518
# start saving 4519
# start saving 4520
# start saving 4521
# start saving 4522
# start saving 4523
# start saving 4524
# start saving 4525
# start saving 4526
# start saving 4527
# start saving 4528
# start saving 4529
# start saving 4530
# start saving 4531
# start saving 4532
# start saving 4533
# start saving 4534
# start saving 4535
# start saving 4536
# start saving 4537
# start saving 4538
# start saving 4539
# start saving 4540
# start saving 4541
# start saving 4542
# start saving 4543
# start saving 4544
# start saving 4545
# start saving 4546
# start saving 4547
# start saving 4548
# start saving 4549
# start saving 4550
# start saving 4551
# start saving 4552
# start saving 4553
# start saving 4554
# start saving 4555
# start saving 4556
# start saving 4557
# start saving 4558
# start saving 4559
# start saving 4560
# start saving 4561
# start saving 4562
# start saving 4563
# start saving 4564
# start saving 4565
# start saving 4566
# start saving 4567
# start saving 4568
# start saving 4569
# start saving 4570
# start saving 4571
# start saving 4572
# start saving 4573
# start saving 4574
# start saving 4575
# start saving 4576
# start saving 4577
# start saving 4578
# start saving 4579
# start saving 4580
# start saving 4581
# start saving 4582
# start saving 4583
# start saving 4584
# start saving 4585
# start saving 4586
# start saving 4587
# start saving 4588
# start saving 4589
# start saving 4590
# start saving 4591
# start saving 4592
# start saving 4593
# start saving 4594
# start saving 4595
# start saving 4596
# start saving 4597
# start saving 4598
# start saving 4599
# start saving 4600
# 4600 users saved
# 575 errors
# start saving 4601
# start saving 4602
# start saving 4603
# start saving 4604
# start saving 4605
# start saving 4606
# start saving 4607
# start saving 4608
# start saving 4609
# start saving 4610
# start saving 4611
# start saving 4612
# start saving 4613
# start saving 4614
# start saving 4615
# start saving 4616
# start saving 4617
# start saving 4618
# start saving 4619
# start saving 4620
# start saving 4621
# start saving 4622
# start saving 4623
# start saving 4624
# start saving 4625
# start saving 4626
# start saving 4627
# start saving 4628
# start saving 4629
# start saving 4630
# start saving 4631
# start saving 4632
# start saving 4633
# start saving 4634
# start saving 4635
# start saving 4636
# start saving 4637
# start saving 4638
# start saving 4639
# start saving 4640
# start saving 4641
# start saving 4642
# start saving 4643
# start saving 4644
# start saving 4645
# start saving 4646
# start saving 4647
# start saving 4648
# start saving 4649
# start saving 4650
# start saving 4651
# start saving 4652
# start saving 4653
# start saving 4654
# start saving 4655
# start saving 4656
# start saving 4657
# start saving 4658
# start saving 4659
# start saving 4660
# start saving 4661
# start saving 4662
# start saving 4663
# start saving 4664
# start saving 4665
# start saving 4666
# start saving 4667
# start saving 4668
# start saving 4669
# start saving 4670
# start saving 4671
# start saving 4672
# start saving 4673
# start saving 4674
# start saving 4675
# start saving 4676
# start saving 4677
# start saving 4678
# start saving 4679
# start saving 4680
# start saving 4681
# start saving 4682
# start saving 4683
# start saving 4684
# start saving 4685
# start saving 4686
# start saving 4687
# start saving 4688
# start saving 4689
# start saving 4690
# start saving 4691
# start saving 4692
# start saving 4693
# start saving 4694
# start saving 4695
# start saving 4696
# start saving 4697
# start saving 4698
# start saving 4699
# start saving 4700
# 4700 users saved
# 591 errors
# start saving 4701
# start saving 4702
# start saving 4703
# start saving 4704
# start saving 4705
# start saving 4706
# start saving 4707
# start saving 4708
# start saving 4709
# start saving 4710
# start saving 4711
# start saving 4712
# start saving 4713
# start saving 4714
# start saving 4715
# start saving 4716
# start saving 4717
# start saving 4718
# start saving 4719
# start saving 4720
# start saving 4721
# start saving 4722
# start saving 4723
# start saving 4724
# start saving 4725
# start saving 4726
# start saving 4727
# start saving 4728
# start saving 4729
# start saving 4730
# start saving 4731
# start saving 4732
# start saving 4733
# start saving 4734
# start saving 4735
# start saving 4736
# start saving 4737
# start saving 4738
# start saving 4739
# start saving 4740
# start saving 4741
# start saving 4742
# start saving 4743
# start saving 4744
# start saving 4745
# start saving 4746
# start saving 4747
# start saving 4748
# start saving 4749
# start saving 4750
# start saving 4751
# start saving 4752
# start saving 4753
# start saving 4754
# start saving 4755
# start saving 4756
# start saving 4757
# start saving 4758
# start saving 4759
# start saving 4760
# start saving 4761
# start saving 4762
# start saving 4763
# start saving 4764
# start saving 4765
# start saving 4766
# start saving 4767
# start saving 4768
# start saving 4769
# start saving 4770
# start saving 4771
# start saving 4772
# start saving 4773
# start saving 4774
# start saving 4775
# start saving 4776
# start saving 4777
# start saving 4778
# start saving 4779
# start saving 4780
# start saving 4781
# start saving 4782
# start saving 4783
# start saving 4784
# start saving 4785
# start saving 4786
# start saving 4787
# start saving 4788
# start saving 4789
# start saving 4790
# start saving 4791
# start saving 4792
# start saving 4793
# start saving 4794
# start saving 4795
# start saving 4796
# start saving 4797
# start saving 4798
# start saving 4799
# start saving 4800
# 4800 users saved
# 604 errors
# start saving 4801
# start saving 4802
# start saving 4803
# start saving 4804
# start saving 4805
# start saving 4806
# start saving 4807
# start saving 4808
# start saving 4809
# start saving 4810
# start saving 4811
# start saving 4812
# start saving 4813
# start saving 4814
# start saving 4815
# start saving 4816
# start saving 4817
# start saving 4818
# start saving 4819
# start saving 4820
# start saving 4821
# start saving 4822
# start saving 4823
# start saving 4824
# start saving 4825
# start saving 4826
# start saving 4827
# start saving 4828
# start saving 4829
# start saving 4830
# start saving 4831
# start saving 4832
# start saving 4833
# start saving 4834
# start saving 4835
# start saving 4836
# start saving 4837
# start saving 4838
# start saving 4839
# start saving 4840
# start saving 4841
# start saving 4842
# start saving 4843
# start saving 4844
# start saving 4845
# start saving 4846
# start saving 4847
# start saving 4848
# start saving 4849
# start saving 4850
# start saving 4851
# start saving 4852
# start saving 4853
# start saving 4854
# start saving 4855
# start saving 4856
# start saving 4857
# start saving 4858
# start saving 4859
# start saving 4860
# start saving 4861
# start saving 4862
# start saving 4863
# start saving 4864
# start saving 4865
# start saving 4866
# start saving 4867
# start saving 4868
# start saving 4869
# start saving 4870
# start saving 4871
# start saving 4872
# start saving 4873
# start saving 4874
# start saving 4875
# start saving 4876
# start saving 4877
# start saving 4878
# start saving 4879
# start saving 4880
# start saving 4881
# start saving 4882
# start saving 4883
# start saving 4884
# start saving 4885
# start saving 4886
# start saving 4887
# start saving 4888
# start saving 4889
# start saving 4890
# start saving 4891
# start saving 4892
# start saving 4893
# start saving 4894
# start saving 4895
# start saving 4896
# start saving 4897
# start saving 4898
# start saving 4899
# start saving 4900
# 4900 users saved
# 615 errors
# start saving 4901
# start saving 4902
# start saving 4903
# start saving 4904
# start saving 4905
# start saving 4906
# start saving 4907
# start saving 4908
# start saving 4909
# start saving 4910
# start saving 4911
# start saving 4912
# start saving 4913
# start saving 4914
# start saving 4915
# start saving 4916
# start saving 4917
# start saving 4918
# start saving 4919
# start saving 4920
# start saving 4921
# start saving 4922
# start saving 4923
# start saving 4924
# start saving 4925
# start saving 4926
# start saving 4927
# start saving 4928
# start saving 4929
# start saving 4930
# start saving 4931
# start saving 4932
# start saving 4933
# start saving 4934
# start saving 4935
# start saving 4936
# start saving 4937
# start saving 4938
# start saving 4939
# start saving 4940
# start saving 4941
# start saving 4942
# start saving 4943
# start saving 4944
# start saving 4945
# start saving 4946
# start saving 4947
# start saving 4948
# start saving 4949
# start saving 4950
# start saving 4951
# start saving 4952
# start saving 4953
# start saving 4954
# start saving 4955
# start saving 4956
# start saving 4957
# start saving 4958
# start saving 4959
# start saving 4960
# start saving 4961
# start saving 4962
# start saving 4963
# start saving 4964
# start saving 4965
# start saving 4966
# start saving 4967
# start saving 4968
# start saving 4969
# start saving 4970
# start saving 4971
# start saving 4972
# start saving 4973
# start saving 4974
# start saving 4975
# start saving 4976
# start saving 4977
# start saving 4978
# start saving 4979
# start saving 4980
# start saving 4981
# start saving 4982
# start saving 4983
# start saving 4984
# start saving 4985
# start saving 4986
# start saving 4987
# start saving 4988
# start saving 4989
# start saving 4990
# start saving 4991
# start saving 4992
# start saving 4993
# start saving 4994
# start saving 4995
# start saving 4996
# start saving 4997
# start saving 4998
# start saving 4999
# start saving 5000
# 5000 users saved
# 625 errors
# start saving 5001
# start saving 5002
# start saving 5003
# start saving 5004
# start saving 5005
# start saving 5006
# start saving 5007
# start saving 5008
# start saving 5009
# start saving 5010
# start saving 5011
# start saving 5012
# start saving 5013
# start saving 5014
# start saving 5015
# start saving 5016
# start saving 5017
# start saving 5018
# start saving 5019
# start saving 5020
# start saving 5021
# start saving 5022
# start saving 5023
# start saving 5024
# start saving 5025
# start saving 5026
# start saving 5027
# start saving 5028
# start saving 5029
# start saving 5030
# start saving 5031
# start saving 5032
# start saving 5033
# start saving 5034
# start saving 5035
# start saving 5036
# start saving 5037
# start saving 5038
# start saving 5039
# start saving 5040
# start saving 5041
# start saving 5042
# start saving 5043
# start saving 5044
# start saving 5045
# start saving 5046
# start saving 5047
# start saving 5048
# start saving 5049
# start saving 5050
# start saving 5051
# start saving 5052
# start saving 5053
# start saving 5054
# start saving 5055
# start saving 5056
# start saving 5057
# start saving 5058
# start saving 5059
# start saving 5060
# start saving 5061
# start saving 5062
# start saving 5063
# start saving 5064
# start saving 5065
# start saving 5066
# start saving 5067
# start saving 5068
# start saving 5069
# start saving 5070
# start saving 5071
# start saving 5072
# start saving 5073
# start saving 5074
# start saving 5075
# start saving 5076
# start saving 5077
# start saving 5078
# start saving 5079
# start saving 5080
# start saving 5081
# start saving 5082
# start saving 5083
# start saving 5084
# start saving 5085
# start saving 5086
# start saving 5087
# start saving 5088
# start saving 5089
# start saving 5090
# start saving 5091
# start saving 5092
# start saving 5093
# start saving 5094
# start saving 5095
# start saving 5096
# start saving 5097
# start saving 5098
# start saving 5099
# start saving 5100
# 5100 users saved
# 636 errors
# start saving 5101
# start saving 5102
# start saving 5103
# start saving 5104
# start saving 5105
# start saving 5106
# start saving 5107
# start saving 5108
# start saving 5109
# start saving 5110
# start saving 5111
# start saving 5112
# start saving 5113
# start saving 5114
# start saving 5115
# start saving 5116
# start saving 5117
# start saving 5118
# start saving 5119
# start saving 5120
# start saving 5121
# start saving 5122
# start saving 5123
# start saving 5124
# start saving 5125
# start saving 5126
# start saving 5127
# start saving 5128
# start saving 5129
# start saving 5130
# start saving 5131
# start saving 5132
# start saving 5133
# start saving 5134
# start saving 5135
# start saving 5136
# start saving 5137
# start saving 5138
# start saving 5139
# start saving 5140
# start saving 5141
# start saving 5142
# start saving 5143
# start saving 5144
# start saving 5145
# start saving 5146
# start saving 5147
# start saving 5148
# start saving 5149
# start saving 5150
# start saving 5151
# start saving 5152
# start saving 5153
# start saving 5154
# start saving 5155
# start saving 5156
# start saving 5157
# start saving 5158
# start saving 5159
# start saving 5160
# start saving 5161
# start saving 5162
# start saving 5163
# start saving 5164
# start saving 5165
# start saving 5166
# start saving 5167
# start saving 5168
# start saving 5169
# start saving 5170
# start saving 5171
# start saving 5172
# start saving 5173
# start saving 5174
# start saving 5175
# start saving 5176
# start saving 5177
# start saving 5178
# start saving 5179
# start saving 5180
# start saving 5181
# start saving 5182
# start saving 5183
# start saving 5184
# start saving 5185
# start saving 5186
# start saving 5187
# start saving 5188
# start saving 5189
# start saving 5190
# start saving 5191
# start saving 5192
# start saving 5193
# start saving 5194
# start saving 5195
# start saving 5196
# start saving 5197
# start saving 5198
# start saving 5199
# start saving 5200
# 5200 users saved
# 650 errors
# start saving 5201
# start saving 5202
# start saving 5203
# start saving 5204
# start saving 5205
# start saving 5206
# start saving 5207
# start saving 5208
# start saving 5209
# start saving 5210
# start saving 5211
# start saving 5212
# start saving 5213
# start saving 5214
# start saving 5215
# start saving 5216
# start saving 5217
# start saving 5218
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-138-3f9527b55ba6> in <module>()
#      38             user_name=user_link.split("/")[-2].split(".")[0]
#      39
# ---> 40             stat=soup.find_all(class_="section infoBlock")[0].find_all("dd")
#      41             join_date=stat[-6].string.strip()
#      42             beer_karma=stat[-5].string
#
# D:\Anaconda3\lib\site-packages\bs4\element.py in find_all(self, name, attrs, recursive, text, limit, **kwargs)
#    1311         if not recursive:
#    1312             generator = self.children
# -> 1313         return self._find_all(name, attrs, text, limit, generator, **kwargs)
#    1314     findAll = find_all       # BS3
#    1315     findChildren = find_all  # BS2
#
# D:\Anaconda3\lib\site-packages\bs4\element.py in _find_all(self, name, attrs, text, limit, generator, **kwargs)
#     554                 break
#     555             if i:
# --> 556                 found = strainer.search(i)
#     557                 if found:
#     558                     results.append(found)
#
# D:\Anaconda3\lib\site-packages\bs4\element.py in search(self, markup)
#    1702         elif isinstance(markup, Tag):
#    1703             if not self.text or self.name or self.attrs:
# -> 1704                 found = self.search_tag(markup)
#    1705         # If it's text, make sure the text matches.
#    1706         elif isinstance(markup, NavigableString) or \
#
# D:\Anaconda3\lib\site-packages\bs4\element.py in search_tag(self, markup_name, markup_attrs)
#    1674                                 markup_attr_map[k] = v
#    1675                     attr_value = markup_attr_map.get(attr)
# -> 1676                     if not self._matches(attr_value, match_against):
#    1677                         match = False
#    1678                         break
#
# D:\Anaconda3\lib\site-packages\bs4\element.py in _matches(self, markup, match_against, already_tried)
#    1725             # attribute, but maybe we match the attribute value when
#    1726             # considered as a string.
# -> 1727             if self._matches(' '.join(markup), match_against):
#    1728                 return True
#    1729             return False
#
# D:\Anaconda3\lib\site-packages\bs4\element.py in _matches(self, markup, match_against, already_tried)
#    1739         # other ways of matching match the tag name as a string.
#    1740         original_markup = markup
# -> 1741         if isinstance(markup, Tag):
#    1742             markup = markup.name
#    1743
#
# KeyboardInterrupt:

# %% [markdown]
# ### 7. Scrape full beer rating details

# %%
# Read pre-saved list of beer styles
styles=pd.read_csv("styles.csv", encoding="utf-8")
names=styles["style"]
ids=styles["id"]

# Pre-load saved user info
user_urls=set([])
try:
    user_df=pd.read_csv("user_info.csv",encoding="utf-8")
    user_urls=set(user_df["user_url"].tolist())
        
except FileNotFoundError:
    pass


style_id=0

while style_id<len(ids):
    t00=time()
    style_name = "style_"+str(ids[style_id])+".csv"
    style_folder ="C:\\Users\\yjin9\\Documents\\python-scripts\\data_incubator\\data_scraping_cleaning"+ "\\style"+str(ids[style_id])+"\\"
    if not os.path.exists(style_folder):
        os.mkdir(style_folder)
    df=pd.read_csv(style_name, encoding="utf-8")
    
    beer_ids = df["beer_ids"]
    beer_links=df["beer_links"]
    beer_ratings=df["ratings"]

    summary_file_path =os.path.join(style_folder,"style_"+str(ids[style_id])+"_summary"+".csv")
    try:
        beer_summary_df=pd.read_csv(summary_file_path,encoding="utf-8")
        beer_ids_2=beer_summary_df["beer_ids"].tolist()
        ranks=beer_summary_df["beer_ids"].tolist()
        reviews_nums=beer_summary_df["reviews_nums"].tolist()
        pDevs=beer_summary_df["pDevs"].tolist()
        bro_scores=beer_summary_df["bro_scores"].tolist()
        availabilities=beer_summary_df["availabilities"].tolist()
        ibus=beer_summary_df["ibus"].tolist()
        
    except FileNotFoundError:
        beer_ids_2=[]
        ranks=[]
        reviews_nums=[]
        pDevs=[]
        bro_scores=[]
        availabilities=[]
        ibus=[]
    
    # Start from previous 
    beer_idx=len(beer_ids_2)
    while beer_idx<len(beer_ids):
        t0=time()
        beer_url = beer_links[beer_idx]
        beer_id = beer_ids[beer_idx]
        file_path =os.path.join(style_folder,"beer_"+str(beer_id)+".csv")
        
        print("Start beer {}".format(beer_idx))
        ## get beer stats summary from beer page
        r = requests.get(beer_url)
        soup = BeautifulSoup(r.content,"lxml")
        beer_stats=soup.find_all(id="item_stats")[0].find_all("dd")
        
        rank=beer_stats[0].contents[0][1:]
        reviews_num=beer_stats[1].contents[0].contents[0]
        pDev=beer_stats[3].contents[0].contents[0].strip()
        bro_score=beer_stats[4].contents[0].contents[-2].contents[0]
        
        beer_info = soup.find_all(id="info_box")[0].contents
        try:
            availability=beer_info[37].strip()
        except TypeError:
            availability="N/A"
        ibu=beer_info[-7].strip()
        if ibu[-3:]!="IBU":
            ibu="N/A"
        
        beer_ids_2.append(beer_id)
        ranks.append(rank)
        reviews_nums.append(reviews_num)
        pDevs.append(pDev)
        bro_scores.append(bro_score)
        availabilities.append(availability)
        ibus.append(ibu)
        
        ## get beer comments (texts and ratings)
        if locale.atoi(str(beer_ratings[beer_idx]))>0:

            user_ids=[]
            comments_txt=[]
            ba_scores=[]
            rDevs=[]
            looks=[]
            smells=[]
            tastes=[]
            feels=[]
            overalls=[]

            if locale.atoi(str(beer_ratings[beer_idx]))>25:
                comment_end = soup.find_all(attrs={"style":"font-weight:bold;"})[0].find_all(href=re.compile("/beer/profile/"))[-1].get("href").split("=")[-1]
                comment_end = int(comment_end)
            else:
                comment_end = 0
            
            comment_page=0
            while comment_page<=comment_end//25: 
                comment_url =  beer_url+"?view=beer&sort=&start="+str(comment_page*25)
                r = requests.get(comment_url)
                soup = BeautifulSoup(r.content,"lxml")
                comments=soup.find_all(id="rating_fullview_container")
                for i in range(len(comments)):
                    user_id=comments[i].get("ba-user")
                    user_url=comments[i].find_all(class_="username")[0].get("href")
                    user_urls.update([user_url])

                    detail_rating=comments[i].find_all(id="rating_fullview_content_2")[0].contents

                    if len(detail_rating)>9:
                        comment_text="".join([str(item) for item in detail_rating[8:-6] if type(item)==bs4.element.NavigableString])
                    else:
                        comment_text="N/A"

                    ba_score=detail_rating[0].contents[0]
                    if detail_rating[3].string==None:
                        rDev="0%"
                        by_dim_idx=4
                    else:
                        rDev=detail_rating[3].contents[0]
                        by_dim_idx=5
                    try:
                        by_dim=detail_rating[by_dim_idx].contents[0].split("|")
                        look=by_dim[0].split(":")[-1].strip()
                        smell=by_dim[1].split(":")[-1].strip()
                        taste=by_dim[2].split(":")[-1].strip()
                        feel=by_dim[3].split(":")[-1].strip()
                        overall=by_dim[4].split(":")[-1].strip()
                    except IndexError:
                        look="N/A"
                        smell="N/A"
                        taste="N/A"
                        feel="N/A"
                        overall="N/A"                 

                    user_ids.append(user_id)
                    comments_txt.append(comment_text)
                    ba_scores.append(ba_score)
                    rDevs.append(rDev)
                    looks.append(look)
                    smells.append(smell)
                    tastes.append(taste)
                    feels.append(feel)
                    overalls.append(overall)
                #print("-- Comment page {} done".format(comment_page))
                comment_page+=1

            beer_df=pd.DataFrame({"user_id":pd.Series(user_ids),"comments":pd.Series(comments_txt),"ba_score":pd.Series(ba_scores),
                                  "rDev":pd.Series(rDevs),"look":pd.Series(looks),"smell":pd.Series(smells),"taste":pd.Series(tastes),
                                  "feel":pd.Series(feels),"overall":pd.Series(overalls)})
            beer_df.to_csv(file_path,encoding="utf-8")
        
            print("Finish beer {}".format(beer_idx))
            print("{} sec".format(round(time()-t0)))
        
            user_df=pd.DataFrame({"user_url":pd.Series(list(user_urls))})
            user_df.to_csv("user_info.csv",encoding="utf-8")
        else:
            print("Beer {} has 0 rating".format(beer_idx))
        
        beer_idx+=1
    
        ## TO DO beer_summary_df merge with df
        beer_summary_df=pd.DataFrame({"beer_ids":pd.Series(beer_ids_2),"ranks":pd.Series(ranks),"reviews_nums":pd.Series(reviews_nums),"pDevs":pd.Series(pDevs),
                                      "bro_scores":pd.Series(bro_scores),"availabilities":pd.Series(availabilities),"ibus":pd.Series(ibus)})
        beer_summary_df.to_csv(summary_file_path,encoding="utf-8")
    
    print("All beers in style {} are done".format(ids[style_id]))
    assert(beer_summary_df.shape[0]==len(beer_ids))
    
    minutes=round((t00-time())/60)
    print("{} mins".format(minutes))
    style_id+=1
# Out:
# All beers in style 128 are done
# 0 mins
# All beers in style 19 are done
# 0 mins
# All beers in style 175 are done
# 0 mins
# All beers in style 99 are done
# 0 mins
# All beers in style 73 are done
# 0 mins
# All beers in style 94 are done
# 0 mins
# Start beer 27
# Finish beer 27
# 104 sec
# Start beer 28
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# D:\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             try:  # Python 2.7, use buffering of HTTP responses
# --> 379                 httplib_response = conn.getresponse(buffering=True)
#     380             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-311d0e3bd263> in <module>()
#     106             while comment_page<=comment_end//25:
#     107                 comment_url =  beer_url+"?view=beer&sort=&start="+str(comment_page*25)
# --> 108                 r = requests.get(comment_url)
#     109                 soup = BeautifulSoup(r.content,"lxml")
#     110                 comments=soup.find_all(id="rating_fullview_container")
#
# D:\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# D:\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# D:\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     516         }
#     517         send_kwargs.update(settings)
# --> 518         resp = self.send(prep, **send_kwargs)
#     519
#     520         return resp
#
# D:\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     637
#     638         # Send the request
# --> 639         r = adapter.send(request, **kwargs)
#     640
#     641         # Total elapsed time of the request (approximately)
#
# D:\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     436                     decode_content=False,
#     437                     retries=self.max_retries,
# --> 438                     timeout=timeout
#     439                 )
#     440
#
# D:\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# D:\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     380             except TypeError:  # Python 2.6 and older, Python 3
#     381                 try:
# --> 382                     httplib_response = conn.getresponse()
#     383                 except Exception as e:
#     384                     # Remove the TypeError from the exception chain in Python 3;
#
# D:\Anaconda3\lib\http\client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# D:\Anaconda3\lib\http\client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# D:\Anaconda3\lib\http\client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# D:\Anaconda3\lib\socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# D:\Anaconda3\lib\site-packages\requests\packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     275     def recv_into(self, *args, **kwargs):
#     276         try:
# --> 277             return self.connection.recv_into(*args, **kwargs)
#     278         except OpenSSL.SSL.SysCallError as e:
#     279             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# D:\Anaconda3\lib\site-packages\OpenSSL\SSL.py in recv_into(self, buffer, nbytes, flags)
#    1544             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1545         else:
# -> 1546             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1547         self._raise_ssl_error(self._ssl, result)
#    1548
#
# KeyboardInterrupt:

# %%
me="xxxxxxxx"
you="xxxxxxxx"
msg="Interrupt!"
password="xxxxxxxx"
server = smtplib.SMTP('smtp.gmail.com:587')
server.ehlo()
server.starttls()
server.login(me,password)
server.sendmail(me, you, msg)
server.quit()

# %%
#### User Page

# beers
# beer karma
# Out:
# 14998

# %% [markdown]
# [Rating explained](https://www.beeradvocate.com/community/threads/beeradvocate-ratings-explained.184726/)
#
# - controversial beer: high pDev
#
# - picky user: negative rDev
#
# [How to review a beer](https://www.beeradvocate.com/community/threads/how-to-review-a-beer.241156/)
